# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import train_cluster_cifar_dfca_tf as DFCA
import pickle

import numpy as np

from util import *
# Out:
# WARNING:tensorflow:From d:\GIT Repos\decentralized-ifca\cifar_tf\notebooks\exp_dfca-gi\train_cluster_cifar_dfca_tf.py:14: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From e:\anaconda\envs\dl-new\lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# Reads Config file and prepares the arguments you can choose in the config_dfca.json/config_ifca.json

# %%
# theoretically irrelevant here because we initialize the model seed randomly (see find_good_initializer())
seeds = [11,12,13]
learning_rates = [0.25]

dfca_gi = []
ifca = []

# %% [markdown]
# Running the dfca-gi experiment

# %%
import json
import time
import torch
import numpy as np


with open("config.json", "r") as read_file:
    config = json.load(read_file)

for lr in learning_rates:
    config['lr'] = lr
    res_final = []

    for seed in seeds:
        print(f"---------------------------------DFCA-GI, lr: {lr}, seed: {seed}---------------------------------")
        start_time = time.time()
        config['data_seed'] = seed
        config['train_seed'] = config['data_seed']

        print("config:",config)

        exp = DFCA.TrainCIFARCluster(config)
        exp.setup()
        res = exp.run()
        res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
        del exp
        duration = (time.time() - start_time)
        print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))

    res_mean = np.mean(res_final, axis=0).tolist()
    dfca_gi.append(res_mean)
# Out:
# ---------------------------------DFCA-GI, lr: 0.25, seed: 11---------------------------------
# config: {'m': 200, 'm_test': 40, 'p': 2, 'n': 500, 'participation_rate': 0.3, 'num_epochs': 600, 'batch_size': 50, 'tau': 5, 'lr': 0.25, 'data_seed': 11, 'train_seed': 11, 'project_dir': 'output'}
# WARNING:tensorflow:From d:\GIT Repos\decentralized-ifca\cifar_tf\notebooks\exp_dfca-gi\train_cluster_cifar_dfca_tf.py:185: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\GIT Repos\decentralized-ifca\cifar_tf\notebooks\exp_dfca-gi\cifar10.py:143: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From d:\GIT Repos\decentralized-ifca\cifar_tf\notebooks\exp_dfca-gi\cifar10.py:231: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From d:\GIT Repos\decentralized-ifca\cifar_tf\notebooks\exp_dfca-gi\train_cluster_cifar_dfca_tf.py:201: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From d:\GIT Repos\decentralized-ifca\cifar_tf\notebooks\exp_dfca-gi\train_cluster_cifar_dfca_tf.py:803: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
#
# finding good initializer from train data
# Epoch -1 tr: l 4.674 a 0.094  clct[np.int64(0), np.int64(60)] ans[np.int64(31), np.int64(29)] cl_acc 0.517 9.019sec
# Epoch -1 tr: l 4.678 a 0.110  clct[np.int64(4), np.int64(56)] ans[np.int64(33), np.int64(27)] cl_acc 0.517 8.558sec
# Epoch -1 tr: l 4.670 a 0.103  clct[np.int64(45), np.int64(15)] ans[np.int64(31), np.int64(29)] cl_acc 0.600 8.559sec
# Epoch -1 tr: l 4.673 a 0.104  clct[np.int64(52), np.int64(8)] ans[np.int64(29), np.int64(31)] cl_acc 0.517 8.665sec
# Epoch -1 tr: l 4.674 a 0.104  clct[np.int64(53), np.int64(7)] ans[np.int64(30), np.int64(30)] cl_acc 0.517 8.792sec
# Epoch -1 tr: l 4.676 a 0.102  clct[np.int64(54), np.int64(6)] ans[np.int64(30), np.int64(30)] cl_acc 0.533 9.286sec
# Epoch -1 tr: l 4.675 a 0.100  clct[np.int64(5), np.int64(55)] ans[np.int64(33), np.int64(27)] cl_acc 0.533 9.007sec
# Epoch -1 tr: l 4.676 a 0.124  clct[np.int64(10), np.int64(50)] ans[np.int64(25), np.int64(35)] cl_acc 0.550 9.092sec
# Epoch -1 tr: l 4.678 a 0.111  clct[np.int64(5), np.int64(55)] ans[np.int64(29), np.int64(31)] cl_acc 0.600 9.229sec
# Epoch -1 tr: l 4.673 a 0.098  clct[np.int64(1), np.int64(59)] ans[np.int64(30), np.int64(30)] cl_acc 0.517 8.553sec
# Epoch -1 tr: l 4.670 a 0.096  clct[np.int64(59), np.int64(1)] ans[np.int64(27), np.int64(33)] cl_acc 0.567 8.506sec
# Epoch -1 tr: l 4.675 a 0.106  clct[np.int64(48), np.int64(12)] ans[np.int64(29), np.int64(31)] cl_acc 0.617 8.814sec
# Epoch -1 tr: l 4.672 a 0.087  clct[np.int64(1), np.int64(59)] ans[np.int64(33), np.int64(27)] cl_acc 0.567 9.317sec
# Epoch -1 tr: l 4.675 a 0.095  clct[np.int64(1), np.int64(59)] ans[np.int64(26), np.int64(34)] cl_acc 0.550 8.498sec
# Epoch -1 tr: l 4.670 a 0.100  clct[np.int64(60), np.int64(0)] ans[np.int64(29), np.int64(31)] cl_acc 0.517 8.729sec
# Epoch -1 tr: l 4.674 a 0.103  clct[np.int64(7), np.int64(53)] ans[np.int64(32), np.int64(28)] cl_acc 0.517 8.760sec
# Epoch -1 tr: l 4.673 a 0.095  clct[np.int64(20), np.int64(40)] ans[np.int64(27), np.int64(33)] cl_acc 0.683 8.636sec
# Epoch -1 tr: l 4.675 a 0.088  clct[np.int64(58), np.int64(2)] ans[np.int64(27), np.int64(33)] cl_acc 0.517 8.751sec
# Epoch -1 tr: l 4.672 a 0.102  clct[np.int64(21), np.int64(39)] ans[np.int64(30), np.int64(30)] cl_acc 0.583 8.505sec
# Epoch -1 tr: l 4.677 a 0.110  clct[np.int64(8), np.int64(52)] ans[np.int64(29), np.int64(31)] cl_acc 0.617 8.523sec
# Epoch -1 tr: l 4.675 a 0.108  clct[np.int64(12), np.int64(48)] ans[np.int64(30), np.int64(30)] cl_acc 0.633 8.540sec
# Epoch -1 tr: l 4.676 a 0.095  clct[np.int64(60), np.int64(0)] ans[np.int64(31), np.int64(29)] cl_acc 0.517 8.562sec
# Epoch -1 tr: l 4.675 a 0.104  clct[np.int64(2), np.int64(58)] ans[np.int64(33), np.int64(27)] cl_acc 0.517 8.521sec
# Epoch -1 tr: l 4.675 a 0.100  clct[np.int64(57), np.int64(3)] ans[np.int64(26), np.int64(34)] cl_acc 0.583 8.527sec
# Epoch -1 tr: l 4.674 a 0.095  clct[np.int64(60), np.int64(0)] ans[np.int64(23), np.int64(37)] cl_acc 0.617 8.516sec
# Epoch -1 tr: l 4.676 a 0.099  clct[np.int64(13), np.int64(47)] ans[np.int64(29), np.int64(31)] cl_acc 0.533 8.505sec
# Epoch -1 tr: l 4.675 a 0.105  clct[np.int64(49), np.int64(11)] ans[np.int64(28), np.int64(32)] cl_acc 0.517 8.596sec
# Epoch -1 tr: l 4.674 a 0.097  clct[np.int64(55), np.int64(5)] ans[np.int64(28), np.int64(32)] cl_acc 0.517 8.790sec
# Epoch -1 tr: l 4.676 a 0.104  clct[np.int64(24), np.int64(36)] ans[np.int64(32), np.int64(28)] cl_acc 0.533 8.474sec
# found good initializer
# Epoch -1 tr: l 4.676 a 0.106  clct[np.int64(23), np.int64(37)] ans[np.int64(32), np.int64(28)] cl_acc 0.550 8.474sec
# Epoch -1 tst: l 4.677 a 0.104  clct[np.int64(9), np.int64(31)] ans[np.int64(20), np.int64(20)] cl_acc 0.575 5.576sec
# Epoch 0 tr: l 4.584 a 0.128  clct[np.int64(29), np.int64(31)] ans[np.int64(34), np.int64(26)] lr 0.250000 cl_acc 0.583 45.926sec(train) 8.191sec(infer)
# Epoch 0 tst: l 4.584 a 0.132  clct[np.int64(12), np.int64(28)] ans[np.int64(20), np.int64(20)] cl_acc 0.600 5.940sec
# result written at output\results.pickle
# Epoch 1 tr: l 4.483 a 0.151  clct[np.int64(32), np.int64(28)] ans[np.int64(34), np.int64(26)] lr 0.247500 cl_acc 0.567 46.744sec(train) 8.303sec(infer)
# Epoch 1 tst: l 4.501 a 0.153  clct[np.int64(17), np.int64(23)] ans[np.int64(20), np.int64(20)] cl_acc 0.675 5.472sec
# Epoch 2 tr: l 4.376 a 0.177  clct[np.int64(40), np.int64(20)] ans[np.int64(24), np.int64(36)] lr 0.245025 cl_acc 0.600 46.210sec(train) 8.373sec(infer)
# Epoch 2 tst: l 4.422 a 0.162  clct[np.int64(21), np.int64(19)] ans[np.int64(20), np.int64(20)] cl_acc 0.775 5.466sec
# Epoch 3 tr: l 4.315 a 0.179  clct[np.int64(40), np.int64(20)] ans[np.int64(29), np.int64(31)] lr 0.242575 cl_acc 0.517 45.767sec(train) 8.296sec(infer)
# Epoch 3 tst: l 4.350 a 0.181  clct[np.int64(25), np.int64(15)] ans[np.int64(20), np.int64(20)] cl_acc 0.775 5.524sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 24
#      22 exp = DFCA.TrainCIFARCluster(config)
#      23 exp.setup()
# ---> 24 res = exp.run()
#      25 res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#      26 del exp
#
# File d:\GIT Repos\decentralized-ifca\cifar_tf\notebooks\exp_dfca-gi\train_cluster_cifar_dfca_tf.py:351, in TrainCIFARCluster.run(self)
#     348 result['lr'] = lr
#     350 t0 = time.time()
# --> 351 result['train'] = self.train(lr = lr)
#     352 t1 = time.time()
#     353 train_time = t1-t0
#
# File d:\GIT Repos\decentralized-ifca\cifar_tf\notebooks\exp_dfca-gi\train_cluster_cifar_dfca_tf.py:524, in TrainCIFARCluster.train(self, lr)
#     517 t01 = time.time()
#     519 fd0 = {
#     520     self.x_pl:X_b,
#     521     self.y_pl:y_b,
#     522     self.lr_pl:self.lr
#     523 }
# --> 524 self.sess.run([self.train_op], feed_dict= fd0)
#     526 t02 = time.time()
#     528 time_load_data += t01 - t00
#
# File e:\anaconda\envs\dl-new\lib\site-packages\tensorflow\python\client\session.py:977, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     974 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     976 try:
# --> 977   result = self._run(None, fetches, feed_dict, options_ptr,
#     978                      run_metadata_ptr)
#     979   if run_metadata:
#     980     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File e:\anaconda\envs\dl-new\lib\site-packages\tensorflow\python\client\session.py:1220, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1217 # We only want to really perform the run if fetches or targets are provided,
#    1218 # or if the call is a partial run that specifies feeds.
#    1219 if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1220   results = self._do_run(handle, final_targets, final_fetches,
#    1221                          feed_dict_tensor, options, run_metadata)
#    1222 else:
#    1223   results = []
#
# File e:\anaconda\envs\dl-new\lib\site-packages\tensorflow\python\client\session.py:1400, in BaseSession._do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1397   return self._call_tf_sessionprun(handle, feed_dict, fetch_list)
#    1399 if handle is None:
# -> 1400   return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1401                        run_metadata)
#    1402 else:
#    1403   return self._do_call(_prun_fn, handle, feeds, fetches)
#
# File e:\anaconda\envs\dl-new\lib\site-packages\tensorflow\python\client\session.py:1407, in BaseSession._do_call(self, fn, *args)
#    1405 def _do_call(self, fn, *args):
#    1406   try:
# -> 1407     return fn(*args)
#    1408   except errors.OpError as e:
#    1409     message = compat.as_text(e.message)
#
# File e:\anaconda\envs\dl-new\lib\site-packages\tensorflow\python\client\session.py:1390, in BaseSession._do_run.<locals>._run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1387 def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1388   # Ensure any changes to the graph are reflected in the runtime.
#    1389   self._extend_graph()
# -> 1390   return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1391                                   target_list, run_metadata)
#
# File e:\anaconda\envs\dl-new\lib\site-packages\tensorflow\python\client\session.py:1483, in BaseSession._call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1481 def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1482                         run_metadata):
# -> 1483   return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1484                                           fetch_list, target_list,
#    1485                                           run_metadata)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Plots

# %%
r_dfca_gi = {}

r_dfca_gi['test_loss'] = []
r_dfca_gi['test_acc'] = []
r_dfca_gi['cl_acc'] = []
r_dfca_gi['train_loss'] = []
for i in range(len(learning_rates)):
    r_dfca_gi['test_loss'].append(dfca_gi[i][0])
    r_dfca_gi['test_acc'].append(dfca_gi[i][1])
    r_dfca_gi['cl_acc'].append(dfca_gi[i][2])
    r_dfca_gi['train_loss'].append(dfca_gi[i][3])

with open('res_dfca.pickle', 'wb') as f:
    pickle.dump(r_dfca_gi, f)

os.makedirs('graphs', exist_ok=True)

for l in range(len(learning_rates)):

    plt.figure(figsize=(10,5))
    plt.plot(r_dfca_gi['train_loss'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title(f'Train Loss per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.savefig(os.path.join('graphs', '3_train_loss.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_dfca_gi['test_loss'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title(f'Test Loss per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.savefig(os.path.join('graphs', '3_test_loss.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_dfca_gi['test_acc'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch')
    plt.ylabel('test accuracy')
    plt.title(f'Test Accuracy per Epoch (lr={learning_rates[l]})')
    plt.legend()
    plt.savefig(os.path.join('graphs', '3_test_acc.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_dfca_gi['cl_acc'][l][:31], label='dfca-gi', color='green')
    plt.xlabel('epoch')
    plt.ylabel('test accuracy')
    plt.title(f'Clustering Accuracy (lr={learning_rates[l]})')
    plt.legend()
    plt.savefig(os.path.join('graphs', '3_cl_acc.png'))
