# %%
import json
import os
import time
import ipyparallel as ipp

import matplotlib.pyplot as plt
import torch
import dfca as DFCA
import ifca as IFCA

import numpy as np

from util import *

# %% [markdown]
# Reads Config file and prepares the arguments you can choose in the config_dfca.json/config_ifca.json

# %%
rc = ipp.Cluster(n=3).start_and_connect_sync()
rc.activate()

rc.ids 

dview = rc[:]
# Out:
# Starting 3 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/3 [00:00<?, ?engine/s]

# %%
learning_rates = [0.1]

dfca_gi = []
ifca = []
dfca_li = []

# %%
# %%px --targets all
#
# import sys
# import os
# import random
# sys.path.append(os.getcwd())
#
# random.seed(42)
# seeds = random.sample(range(10000), 5)
# learning_rates = [0.1]
#
# dfca_gi = []
# dfca_li = []
# ifca = []

# %% [markdown]
# Running the dfca-gi experiment

# %%
# %%px --target 0 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
#
# with open("config_dfca_gi.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------DFCA-GI, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     dfca_gi.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %%
# %%px --target 1 --noblock
# import dfca as DFCA
# import json
# import time
# import torch
# import numpy as np
#
#
# with open("config_dfca_li.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------DFCA-LI, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = DFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     dfca_li.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# Running the ifca experiment

# %%
# %%px --target 2 --noblock
# import ifca as IFCA
# import json
# import time
# import torch
# import numpy as np
#
# with open("config_ifca.json", "r") as read_file:
#     config = json.load(read_file)
#
# for lr in learning_rates:
#     config['lr'] = lr
#     res_final = []
#
#     for seed in seeds:
#         print(f"---------------------------------IFCA, lr: {lr}, seed: {seed}---------------------------------")
#         start_time = time.time()
#         config['data_seed'] = seed
#         config['train_seed'] = config['data_seed']
#
#         print("config:",config)
#         device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#         print(f"Using device: {device}")
#
#         exp = IFCA.TrainMNISTCluster(config, device)
#         exp.setup()
#         res = exp.run()
#         res_final.append([[r['test']['loss'] for r in res], [r['test']['acc'] for r in res], [r['test']['cl_acc'] for r in res], [r['train']['loss'] for r in res]])
#         del exp
#         duration = (time.time() - start_time)
#         print("---train cluster Ended in %0.2f hour (%.3f sec) " % (duration/float(3600), duration))
#
#     res_mean = np.mean(res_final, axis=0).tolist()
#     ifca.append(res_mean)
# Out:
# <AsyncResult(%px): pending>

# %% [markdown]
# ## Results

# %% [markdown]
# DFCA-GI Experiment Outputs

# %%
rc.wait_interactive()
_.display_outputs()

dfca_gi = rc[0].pull('dfca_gi', block=True)
dfca_li = rc[1].pull('dfca_li', block=True)
ifca = rc[2].pull('ifca', block=True)
# Out:
# unknown:   0%|          | 0/3 [00:00<?, ?tasks/s]
# ---------------------------------IFCA, lr: 0.1, seed: 1824---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'h1': 200, 'num_epochs': 300, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_ifca'}
# Using device: cuda:0
# Epoch -1 tr: l 2.292 a 0.116 clct[np.int64(892), np.int64(109), np.int64(140), np.int64(59)] cl_acc 0.321  19.077sec
# Epoch -1 tst: l 2.292 a 0.114 clct[np.int64(151), np.int64(13), np.int64(22), np.int64(14)] cl_acc 0.305  4.697sec
# Epoch 0 tr: l 2.194 a 0.283 clct[np.int64(408), np.int64(354), np.int64(296), np.int64(142)] cl_acc 0.745  lr 0.100000 33.823sec(train) 25.067sec(infer)
# Epoch 0 tst: l 2.193 a 0.285 clct[np.int64(68), np.int64(58), np.int64(53), np.int64(21)] cl_acc 0.765  3.322sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 1 tr: l 1.956 a 0.571 clct[np.int64(293), np.int64(305), np.int64(303), np.int64(299)] cl_acc 0.990  lr 0.100000 21.486sec(train) 25.004sec(infer)
# Epoch 1 tst: l 1.948 a 0.575 clct[np.int64(48), np.int64(52), np.int64(50), np.int64(50)] cl_acc 0.990  4.206sec
# Epoch 2 tr: l 1.614 a 0.722 clct[np.int64(300), np.int64(300), np.int64(301), np.int64(299)] cl_acc 0.999  lr 0.100000 21.921sec(train) 23.916sec(infer)
# Epoch 2 tst: l 1.597 a 0.727 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.633sec
# Epoch 3 tr: l 1.295 a 0.772 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.786sec(train) 26.394sec(infer)
# Epoch 3 tst: l 1.272 a 0.780 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.121sec
# Epoch 4 tr: l 1.055 a 0.802 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.291sec(train) 26.872sec(infer)
# Epoch 4 tst: l 1.029 a 0.807 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.491sec
# Epoch 5 tr: l 0.891 a 0.821 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.527sec(train) 23.942sec(infer)
# Epoch 5 tst: l 0.864 a 0.826 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.638sec
# Epoch 6 tr: l 0.779 a 0.834 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.657sec(train) 24.026sec(infer)
# Epoch 6 tst: l 0.751 a 0.839 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.322sec
# Epoch 7 tr: l 0.699 a 0.844 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.591sec(train) 27.114sec(infer)
# Epoch 7 tst: l 0.671 a 0.851 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.005sec
# Epoch 8 tr: l 0.640 a 0.852 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.992sec(train) 26.025sec(infer)
# Epoch 8 tst: l 0.613 a 0.858 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.317sec
# Epoch 9 tr: l 0.595 a 0.858 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.042sec(train) 23.327sec(infer)
# Epoch 9 tst: l 0.568 a 0.864 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.602sec
# Epoch 10 tr: l 0.559 a 0.863 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.598sec(train) 24.182sec(infer)
# Epoch 10 tst: l 0.532 a 0.870 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.639sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 11 tr: l 0.531 a 0.867 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 20.365sec(train) 29.632sec(infer)
# Epoch 11 tst: l 0.504 a 0.875 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.598sec
# Epoch 12 tr: l 0.507 a 0.871 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.633sec(train) 30.059sec(infer)
# Epoch 12 tst: l 0.481 a 0.879 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.249sec
# Epoch 13 tr: l 0.487 a 0.874 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.698sec(train) 26.873sec(infer)
# Epoch 13 tst: l 0.461 a 0.882 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.138sec
# Epoch 14 tr: l 0.470 a 0.877 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.621sec(train) 24.986sec(infer)
# Epoch 14 tst: l 0.445 a 0.885 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.944sec
# Epoch 15 tr: l 0.456 a 0.879 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.048sec(train) 8.819sec(infer)
# Epoch 15 tst: l 0.431 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  1.131sec
# Epoch 16 tr: l 0.443 a 0.881 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 18.729sec(train) 6.342sec(infer)
# Epoch 16 tst: l 0.418 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  1.020sec
# Epoch 17 tr: l 0.432 a 0.883 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 17.149sec(train) 6.115sec(infer)
# Epoch 17 tst: l 0.408 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  0.967sec
# Epoch 18 tr: l 0.422 a 0.885 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 16.908sec(train) 7.978sec(infer)
# Epoch 18 tst: l 0.398 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  1.146sec
# Epoch 19 tr: l 0.414 a 0.887 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.075sec(train) 29.145sec(infer)
# Epoch 19 tst: l 0.390 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.512sec
# Epoch 20 tr: l 0.406 a 0.888 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.916sec(train) 28.300sec(infer)
# Epoch 20 tst: l 0.382 a 0.894 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.960sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 21 tr: l 0.399 a 0.889 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.650sec(train) 25.143sec(infer)
# Epoch 21 tst: l 0.375 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.557sec
# Epoch 22 tr: l 0.392 a 0.891 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.224sec(train) 25.948sec(infer)
# Epoch 22 tst: l 0.369 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.019sec
# Epoch 23 tr: l 0.386 a 0.892 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.947sec(train) 27.320sec(infer)
# Epoch 23 tst: l 0.364 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.273sec
# Epoch 24 tr: l 0.381 a 0.893 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.869sec(train) 26.565sec(infer)
# Epoch 24 tst: l 0.359 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.605sec
# Epoch 25 tr: l 0.376 a 0.894 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.678sec(train) 26.349sec(infer)
# Epoch 25 tst: l 0.354 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.662sec
# Epoch 26 tr: l 0.371 a 0.895 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.750sec(train) 27.740sec(infer)
# Epoch 26 tst: l 0.349 a 0.900 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.285sec
# Epoch 27 tr: l 0.367 a 0.896 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.549sec(train) 27.284sec(infer)
# Epoch 27 tst: l 0.345 a 0.901 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.373sec
# Epoch 28 tr: l 0.363 a 0.897 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.944sec(train) 25.547sec(infer)
# Epoch 28 tst: l 0.342 a 0.902 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.347sec
# Epoch 29 tr: l 0.359 a 0.897 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.979sec(train) 27.199sec(infer)
# Epoch 29 tst: l 0.338 a 0.903 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.010sec
# Epoch 30 tr: l 0.355 a 0.898 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.564sec(train) 29.230sec(infer)
# Epoch 30 tst: l 0.335 a 0.903 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.350sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 31 tr: l 0.352 a 0.899 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.055sec(train) 26.859sec(infer)
# Epoch 31 tst: l 0.332 a 0.904 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.317sec
# Epoch 32 tr: l 0.349 a 0.899 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.138sec(train) 24.172sec(infer)
# Epoch 32 tst: l 0.329 a 0.905 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.411sec
# Epoch 33 tr: l 0.346 a 0.900 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.129sec(train) 26.370sec(infer)
# Epoch 33 tst: l 0.326 a 0.905 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.009sec
# Epoch 34 tr: l 0.343 a 0.901 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.394sec(train) 30.453sec(infer)
# Epoch 34 tst: l 0.323 a 0.906 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.182sec
# Epoch 35 tr: l 0.340 a 0.901 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.003sec(train) 27.030sec(infer)
# Epoch 35 tst: l 0.321 a 0.906 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.856sec
# Epoch 36 tr: l 0.337 a 0.902 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.024sec(train) 24.203sec(infer)
# Epoch 36 tst: l 0.318 a 0.907 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.695sec
# Epoch 37 tr: l 0.335 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.096sec(train) 25.455sec(infer)
# Epoch 37 tst: l 0.316 a 0.907 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.982sec
# Epoch 38 tr: l 0.332 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.601sec(train) 29.261sec(infer)
# Epoch 38 tst: l 0.314 a 0.908 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.604sec
# Epoch 39 tr: l 0.330 a 0.904 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.241sec(train) 27.375sec(infer)
# Epoch 39 tst: l 0.312 a 0.909 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.055sec
# Epoch 40 tr: l 0.328 a 0.904 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.100sec(train) 24.718sec(infer)
# Epoch 40 tst: l 0.310 a 0.909 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.649sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 41 tr: l 0.326 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.388sec(train) 26.246sec(infer)
# Epoch 41 tst: l 0.308 a 0.910 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.049sec
# Epoch 42 tr: l 0.323 a 0.906 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.724sec(train) 27.831sec(infer)
# Epoch 42 tst: l 0.306 a 0.910 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.877sec
# Epoch 43 tr: l 0.321 a 0.906 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.504sec(train) 26.288sec(infer)
# Epoch 43 tst: l 0.304 a 0.910 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.711sec
# Epoch 44 tr: l 0.319 a 0.907 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.316sec(train) 25.365sec(infer)
# Epoch 44 tst: l 0.303 a 0.911 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.558sec
# Epoch 45 tr: l 0.317 a 0.907 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.175sec(train) 27.538sec(infer)
# Epoch 45 tst: l 0.301 a 0.911 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.449sec
# Epoch 46 tr: l 0.316 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.589sec(train) 27.609sec(infer)
# Epoch 46 tst: l 0.299 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.379sec
# Epoch 47 tr: l 0.314 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.161sec(train) 24.977sec(infer)
# Epoch 47 tst: l 0.298 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.435sec
# Epoch 48 tr: l 0.312 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.320sec(train) 25.659sec(infer)
# Epoch 48 tst: l 0.296 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.057sec
# Epoch 49 tr: l 0.310 a 0.909 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.080sec(train) 27.747sec(infer)
# Epoch 49 tst: l 0.295 a 0.913 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.064sec
# Epoch 50 tr: l 0.309 a 0.909 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.796sec(train) 30.698sec(infer)
# Epoch 50 tst: l 0.293 a 0.913 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.640sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 51 tr: l 0.307 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.557sec(train) 26.165sec(infer)
# Epoch 51 tst: l 0.292 a 0.914 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.981sec
# Epoch 52 tr: l 0.305 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.869sec(train) 24.087sec(infer)
# Epoch 52 tst: l 0.290 a 0.914 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.926sec
# Epoch 53 tr: l 0.304 a 0.911 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.982sec(train) 27.511sec(infer)
# Epoch 53 tst: l 0.289 a 0.915 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.896sec
# Epoch 54 tr: l 0.302 a 0.911 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.205sec(train) 30.467sec(infer)
# Epoch 54 tst: l 0.288 a 0.915 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.906sec
# Epoch 55 tr: l 0.301 a 0.911 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.476sec(train) 27.540sec(infer)
# Epoch 55 tst: l 0.286 a 0.916 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.563sec
# Epoch 56 tr: l 0.299 a 0.912 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.614sec(train) 24.729sec(infer)
# Epoch 56 tst: l 0.285 a 0.916 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.245sec
# Epoch 57 tr: l 0.298 a 0.912 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.671sec(train) 26.682sec(infer)
# Epoch 57 tst: l 0.284 a 0.917 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.050sec
# Epoch 58 tr: l 0.296 a 0.912 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.973sec(train) 29.679sec(infer)
# Epoch 58 tst: l 0.283 a 0.917 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.058sec
# Epoch 59 tr: l 0.295 a 0.913 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.582sec(train) 26.940sec(infer)
# Epoch 59 tst: l 0.282 a 0.917 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.753sec
# Epoch 60 tr: l 0.294 a 0.913 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.554sec(train) 25.168sec(infer)
# Epoch 60 tst: l 0.280 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.481sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 61 tr: l 0.292 a 0.914 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.191sec(train) 26.745sec(infer)
# Epoch 61 tst: l 0.279 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.410sec
# Epoch 62 tr: l 0.291 a 0.914 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.780sec(train) 29.111sec(infer)
# Epoch 62 tst: l 0.278 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.855sec
# Epoch 63 tr: l 0.290 a 0.914 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.839sec(train) 26.555sec(infer)
# Epoch 63 tst: l 0.277 a 0.919 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.570sec
# Epoch 64 tr: l 0.288 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.499sec(train) 25.828sec(infer)
# Epoch 64 tst: l 0.276 a 0.919 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.985sec
# Epoch 65 tr: l 0.287 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.550sec(train) 27.265sec(infer)
# Epoch 65 tst: l 0.275 a 0.919 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.415sec
# Epoch 66 tr: l 0.286 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.697sec(train) 29.049sec(infer)
# Epoch 66 tst: l 0.274 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.097sec
# Epoch 67 tr: l 0.285 a 0.916 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.980sec(train) 25.640sec(infer)
# Epoch 67 tst: l 0.273 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.557sec
# Epoch 68 tr: l 0.283 a 0.916 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.592sec(train) 25.298sec(infer)
# Epoch 68 tst: l 0.272 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.926sec
# Epoch 69 tr: l 0.282 a 0.916 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.354sec(train) 28.057sec(infer)
# Epoch 69 tst: l 0.271 a 0.921 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.484sec
# Epoch 70 tr: l 0.281 a 0.917 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.309sec(train) 29.481sec(infer)
# Epoch 70 tst: l 0.270 a 0.921 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.223sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 71 tr: l 0.280 a 0.917 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.918sec(train) 25.975sec(infer)
# Epoch 71 tst: l 0.269 a 0.921 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.581sec
# Epoch 72 tr: l 0.279 a 0.917 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.338sec(train) 24.259sec(infer)
# Epoch 72 tst: l 0.268 a 0.921 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.085sec
# Epoch 73 tr: l 0.277 a 0.918 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.183sec(train) 28.312sec(infer)
# Epoch 73 tst: l 0.267 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.981sec
# Epoch 74 tr: l 0.276 a 0.918 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.767sec(train) 30.403sec(infer)
# Epoch 74 tst: l 0.266 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.213sec
# Epoch 75 tr: l 0.275 a 0.918 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.632sec(train) 27.107sec(infer)
# Epoch 75 tst: l 0.265 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.472sec
# Epoch 76 tr: l 0.274 a 0.919 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.589sec(train) 23.916sec(infer)
# Epoch 76 tst: l 0.264 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.836sec
# Epoch 77 tr: l 0.273 a 0.919 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.106sec(train) 24.973sec(infer)
# Epoch 77 tst: l 0.263 a 0.923 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.939sec
# Epoch 78 tr: l 0.272 a 0.919 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.508sec(train) 28.553sec(infer)
# Epoch 78 tst: l 0.262 a 0.923 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  2.410sec
# Epoch 79 tr: l 0.271 a 0.920 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.603sec(train) 28.480sec(infer)
# Epoch 79 tst: l 0.261 a 0.923 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  6.457sec
# Epoch 80 tr: l 0.270 a 0.920 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.735sec(train) 26.060sec(infer)
# Epoch 80 tst: l 0.261 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.138sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 81 tr: l 0.269 a 0.920 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.996sec(train) 24.166sec(infer)
# Epoch 81 tst: l 0.260 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.304sec
# Epoch 82 tr: l 0.268 a 0.921 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.873sec(train) 27.920sec(infer)
# Epoch 82 tst: l 0.259 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.054sec
# Epoch 83 tr: l 0.267 a 0.921 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.038sec(train) 27.724sec(infer)
# Epoch 83 tst: l 0.258 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  6.200sec
# Epoch 84 tr: l 0.266 a 0.921 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.212sec(train) 26.337sec(infer)
# Epoch 84 tst: l 0.257 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.613sec
# Epoch 85 tr: l 0.265 a 0.922 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.162sec(train) 24.629sec(infer)
# Epoch 85 tst: l 0.256 a 0.925 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.284sec
# Epoch 86 tr: l 0.264 a 0.922 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.020sec(train) 27.855sec(infer)
# Epoch 86 tst: l 0.255 a 0.925 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.986sec
# Epoch 87 tr: l 0.263 a 0.922 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.598sec(train) 27.921sec(infer)
# Epoch 87 tst: l 0.255 a 0.925 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.996sec
# Epoch 88 tr: l 0.262 a 0.923 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.608sec(train) 24.539sec(infer)
# Epoch 88 tst: l 0.254 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.640sec
# Epoch 89 tr: l 0.261 a 0.923 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.054sec(train) 25.104sec(infer)
# Epoch 89 tst: l 0.253 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.937sec
# Epoch 90 tr: l 0.260 a 0.923 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 19.411sec(train) 30.199sec(infer)
# Epoch 90 tst: l 0.252 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.062sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 91 tr: l 0.259 a 0.923 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.049sec(train) 27.634sec(infer)
# Epoch 91 tst: l 0.251 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  6.116sec
# Epoch 92 tr: l 0.258 a 0.924 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.290sec(train) 24.400sec(infer)
# Epoch 92 tst: l 0.251 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.842sec
# Epoch 93 tr: l 0.257 a 0.924 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.411sec(train) 24.038sec(infer)
# Epoch 93 tst: l 0.250 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.936sec
# Epoch 94 tr: l 0.256 a 0.924 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.096sec(train) 29.015sec(infer)
# Epoch 94 tst: l 0.249 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.037sec
# Epoch 95 tr: l 0.255 a 0.924 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.281sec(train) 29.261sec(infer)
# Epoch 95 tst: l 0.248 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.334sec
# Epoch 96 tr: l 0.254 a 0.925 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.931sec(train) 25.471sec(infer)
# Epoch 96 tst: l 0.247 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.098sec
# Epoch 97 tr: l 0.253 a 0.925 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.024sec(train) 23.923sec(infer)
# Epoch 97 tst: l 0.247 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.151sec
# Epoch 98 tr: l 0.252 a 0.925 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.289sec(train) 27.995sec(infer)
# Epoch 98 tst: l 0.246 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.973sec
# Epoch 99 tr: l 0.251 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.631sec(train) 27.928sec(infer)
# Epoch 99 tst: l 0.245 a 0.928 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.735sec
# Epoch 100 tr: l 0.251 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.234sec(train) 26.181sec(infer)
# Epoch 100 tst: l 0.244 a 0.928 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.720sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 101 tr: l 0.250 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.900sec(train) 24.568sec(infer)
# Epoch 101 tst: l 0.244 a 0.928 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.345sec
# Epoch 102 tr: l 0.249 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.038sec(train) 28.154sec(infer)
# Epoch 102 tst: l 0.243 a 0.928 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.062sec
# Epoch 103 tr: l 0.248 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.817sec(train) 26.835sec(infer)
# Epoch 103 tst: l 0.242 a 0.928 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.562sec
# Epoch 104 tr: l 0.247 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.491sec(train) 25.557sec(infer)
# Epoch 104 tst: l 0.241 a 0.929 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.457sec
# Epoch 105 tr: l 0.246 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.742sec(train) 25.408sec(infer)
# Epoch 105 tst: l 0.241 a 0.929 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.323sec
# Epoch 106 tr: l 0.245 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.412sec(train) 28.459sec(infer)
# Epoch 106 tst: l 0.240 a 0.929 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.233sec
# Epoch 107 tr: l 0.245 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.946sec(train) 26.558sec(infer)
# Epoch 107 tst: l 0.239 a 0.929 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.888sec
# Epoch 108 tr: l 0.244 a 0.928 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.132sec(train) 25.118sec(infer)
# Epoch 108 tst: l 0.239 a 0.929 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.219sec
# Epoch 109 tr: l 0.243 a 0.928 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.792sec(train) 26.713sec(infer)
# Epoch 109 tst: l 0.238 a 0.929 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.346sec
# Epoch 110 tr: l 0.242 a 0.928 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 18.506sec(train) 29.419sec(infer)
# Epoch 110 tst: l 0.237 a 0.930 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.331sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 111 tr: l 0.241 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 16.294sec(train) 24.976sec(infer)
# Epoch 111 tst: l 0.236 a 0.930 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.582sec
# Epoch 112 tr: l 0.240 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.403sec(train) 24.977sec(infer)
# Epoch 112 tst: l 0.236 a 0.930 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.020sec
# Epoch 113 tr: l 0.240 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.505sec(train) 29.531sec(infer)
# Epoch 113 tst: l 0.235 a 0.930 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.879sec
# Epoch 114 tr: l 0.239 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.255sec(train) 29.487sec(infer)
# Epoch 114 tst: l 0.234 a 0.931 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.193sec
# Epoch 115 tr: l 0.238 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.441sec(train) 25.245sec(infer)
# Epoch 115 tst: l 0.234 a 0.931 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.976sec
# Epoch 116 tr: l 0.237 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.016sec(train) 23.811sec(infer)
# Epoch 116 tst: l 0.233 a 0.931 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.111sec
# Epoch 117 tr: l 0.236 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.953sec(train) 28.285sec(infer)
# Epoch 117 tst: l 0.232 a 0.931 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.891sec
# Epoch 118 tr: l 0.236 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.581sec(train) 31.307sec(infer)
# Epoch 118 tst: l 0.232 a 0.931 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.963sec
# Epoch 119 tr: l 0.235 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.264sec(train) 27.925sec(infer)
# Epoch 119 tst: l 0.231 a 0.931 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  6.087sec
# Epoch 120 tr: l 0.234 a 0.931 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.763sec(train) 24.664sec(infer)
# Epoch 120 tst: l 0.230 a 0.932 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.795sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 121 tr: l 0.233 a 0.931 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.165sec(train) 24.582sec(infer)
# Epoch 121 tst: l 0.230 a 0.932 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.057sec
# Epoch 122 tr: l 0.233 a 0.931 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.966sec(train) 28.825sec(infer)
# Epoch 122 tst: l 0.229 a 0.932 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.930sec
# Epoch 123 tr: l 0.232 a 0.931 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.390sec(train) 27.927sec(infer)
# Epoch 123 tst: l 0.228 a 0.932 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.559sec
# Epoch 124 tr: l 0.231 a 0.931 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.704sec(train) 25.522sec(infer)
# Epoch 124 tst: l 0.228 a 0.932 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.966sec
# Epoch 125 tr: l 0.230 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.509sec(train) 24.639sec(infer)
# Epoch 125 tst: l 0.227 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.265sec
# Epoch 126 tr: l 0.230 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.799sec(train) 28.395sec(infer)
# Epoch 126 tst: l 0.227 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.022sec
# Epoch 127 tr: l 0.229 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 17.555sec(train) 25.863sec(infer)
# Epoch 127 tst: l 0.226 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.628sec
# Epoch 128 tr: l 0.228 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 17.679sec(train) 24.984sec(infer)
# Epoch 128 tst: l 0.225 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.899sec
# Epoch 129 tr: l 0.227 a 0.933 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 16.968sec(train) 29.338sec(infer)
# Epoch 129 tst: l 0.225 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.476sec
# Epoch 130 tr: l 0.227 a 0.933 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.025sec(train) 26.956sec(infer)
# Epoch 130 tst: l 0.224 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  6.454sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 131 tr: l 0.226 a 0.933 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.148sec(train) 24.202sec(infer)
# Epoch 131 tst: l 0.223 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.703sec
# Epoch 132 tr: l 0.225 a 0.933 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.373sec(train) 24.469sec(infer)
# Epoch 132 tst: l 0.223 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.947sec
# Epoch 133 tr: l 0.225 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.451sec(train) 29.676sec(infer)
# Epoch 133 tst: l 0.222 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.036sec
# Epoch 134 tr: l 0.224 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.007sec(train) 28.758sec(infer)
# Epoch 134 tst: l 0.222 a 0.934 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  6.618sec
# Epoch 135 tr: l 0.223 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.502sec(train) 25.274sec(infer)
# Epoch 135 tst: l 0.221 a 0.934 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.089sec
# Epoch 136 tr: l 0.222 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.033sec(train) 23.992sec(infer)
# Epoch 136 tst: l 0.220 a 0.934 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.991sec
# Epoch 137 tr: l 0.222 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.789sec(train) 28.207sec(infer)
# Epoch 137 tst: l 0.220 a 0.934 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.044sec
# Epoch 138 tr: l 0.221 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.167sec(train) 25.224sec(infer)
# Epoch 138 tst: l 0.219 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  8.083sec
# Epoch 139 tr: l 0.220 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 19.400sec(train) 24.063sec(infer)
# Epoch 139 tst: l 0.219 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.722sec
# Epoch 140 tr: l 0.220 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.147sec(train) 24.389sec(infer)
# Epoch 140 tst: l 0.218 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.353sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 141 tr: l 0.219 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.024sec(train) 27.628sec(infer)
# Epoch 141 tst: l 0.218 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.005sec
# Epoch 142 tr: l 0.218 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.660sec(train) 28.040sec(infer)
# Epoch 142 tst: l 0.217 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.837sec
# Epoch 143 tr: l 0.218 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.585sec(train) 26.172sec(infer)
# Epoch 143 tst: l 0.216 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.646sec
# Epoch 144 tr: l 0.217 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.959sec(train) 25.061sec(infer)
# Epoch 144 tst: l 0.216 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.327sec
# Epoch 145 tr: l 0.216 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.026sec(train) 28.003sec(infer)
# Epoch 145 tst: l 0.215 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.249sec
# Epoch 146 tr: l 0.216 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.887sec(train) 26.685sec(infer)
# Epoch 146 tst: l 0.215 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.849sec
# Epoch 147 tr: l 0.215 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.698sec(train) 25.223sec(infer)
# Epoch 147 tst: l 0.214 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.538sec
# Epoch 148 tr: l 0.215 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.450sec(train) 25.507sec(infer)
# Epoch 148 tst: l 0.214 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.156sec
# Epoch 149 tr: l 0.214 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.360sec(train) 28.994sec(infer)
# Epoch 149 tst: l 0.213 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.318sec
# Epoch 150 tr: l 0.213 a 0.937 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.516sec(train) 26.738sec(infer)
# Epoch 150 tst: l 0.212 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.786sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 151 tr: l 0.213 a 0.937 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.113sec(train) 24.162sec(infer)
# Epoch 151 tst: l 0.212 a 0.937 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.571sec
# Epoch 152 tr: l 0.212 a 0.937 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.311sec(train) 25.502sec(infer)
# Epoch 152 tst: l 0.211 a 0.937 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.904sec
# Epoch 153 tr: l 0.211 a 0.937 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.130sec(train) 30.014sec(infer)
# Epoch 153 tst: l 0.211 a 0.937 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.063sec
# Epoch 154 tr: l 0.211 a 0.937 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.015sec(train) 27.798sec(infer)
# Epoch 154 tst: l 0.210 a 0.937 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  6.808sec
# Epoch 155 tr: l 0.210 a 0.937 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.356sec(train) 24.516sec(infer)
# Epoch 155 tst: l 0.210 a 0.937 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.076sec
# Epoch 156 tr: l 0.210 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.051sec(train) 23.984sec(infer)
# Epoch 156 tst: l 0.209 a 0.937 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.971sec
# Epoch 157 tr: l 0.209 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.568sec(train) 29.179sec(infer)
# Epoch 157 tst: l 0.209 a 0.937 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.942sec
# Epoch 158 tr: l 0.208 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.587sec(train) 30.411sec(infer)
# Epoch 158 tst: l 0.208 a 0.937 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.763sec
# Epoch 159 tr: l 0.208 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.071sec(train) 26.573sec(infer)
# Epoch 159 tst: l 0.208 a 0.937 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.327sec
# Epoch 160 tr: l 0.207 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.791sec(train) 24.164sec(infer)
# Epoch 160 tst: l 0.207 a 0.937 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.387sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 161 tr: l 0.206 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.408sec(train) 26.732sec(infer)
# Epoch 161 tst: l 0.207 a 0.938 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.106sec
# Epoch 162 tr: l 0.206 a 0.939 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.951sec(train) 29.024sec(infer)
# Epoch 162 tst: l 0.206 a 0.938 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.715sec
# Epoch 163 tr: l 0.205 a 0.939 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.044sec(train) 26.528sec(infer)
# Epoch 163 tst: l 0.206 a 0.938 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.667sec
# Epoch 164 tr: l 0.205 a 0.939 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.971sec(train) 24.887sec(infer)
# Epoch 164 tst: l 0.205 a 0.938 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.353sec
# Epoch 165 tr: l 0.204 a 0.939 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.996sec(train) 27.227sec(infer)
# Epoch 165 tst: l 0.205 a 0.938 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.090sec
# Epoch 166 tr: l 0.204 a 0.939 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.700sec(train) 28.711sec(infer)
# Epoch 166 tst: l 0.204 a 0.938 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  5.198sec
# Epoch 167 tr: l 0.203 a 0.939 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 21.936sec(train) 24.845sec(infer)
# Epoch 167 tst: l 0.204 a 0.938 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.549sec
# Epoch 168 tr: l 0.202 a 0.940 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.108sec(train) 24.265sec(infer)
# Epoch 168 tst: l 0.203 a 0.939 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.007sec
# Epoch 169 tr: l 0.202 a 0.940 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.209sec(train) 28.946sec(infer)
# Epoch 169 tst: l 0.203 a 0.939 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.054sec
# ...
# Epoch 243 tr: l 0.204 a 0.939 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 21.779sec(train) 37.385sec(infer)
# Epoch 243 tst: l 0.216 a 0.938 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.206sec
# Epoch 244 tr: l 0.204 a 0.939 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 19.863sec(train) 42.473sec(infer)
# Epoch 244 tst: l 0.216 a 0.938 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  6.499sec
# Epoch 245 tr: l 0.203 a 0.939 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 19.666sec(train) 44.544sec(infer)
# Epoch 245 tst: l 0.216 a 0.939 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  6.890sec
# Epoch 246 tr: l 0.203 a 0.939 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 22.431sec(train) 40.991sec(infer)
# Epoch 246 tst: l 0.215 a 0.939 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  4.525sec
# Epoch 247 tr: l 0.202 a 0.940 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.843sec(train) 38.983sec(infer)
# Epoch 247 tst: l 0.215 a 0.939 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  4.472sec
# Epoch 248 tr: l 0.201 a 0.940 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.324sec(train) 43.146sec(infer)
# Epoch 248 tst: l 0.214 a 0.939 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  5.990sec
# Epoch 249 tr: l 0.201 a 0.940 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 22.415sec(train) 46.688sec(infer)
# Epoch 249 tst: l 0.214 a 0.939 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.410sec
# Epoch 250 tr: l 0.200 a 0.940 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.519sec(train) 44.229sec(infer)
# Epoch 250 tst: l 0.213 a 0.939 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  13.180sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 251 tr: l 0.200 a 0.940 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.329sec(train) 41.349sec(infer)
# Epoch 251 tst: l 0.213 a 0.939 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.413sec
# Epoch 252 tr: l 0.199 a 0.940 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.110sec(train) 44.674sec(infer)
# Epoch 252 tst: l 0.212 a 0.940 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.813sec
# Epoch 253 tr: l 0.199 a 0.940 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.579sec(train) 54.615sec(infer)
# Epoch 253 tst: l 0.212 a 0.940 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  4.611sec
# Epoch 254 tr: l 0.198 a 0.940 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.175sec(train) 48.846sec(infer)
# Epoch 254 tst: l 0.211 a 0.940 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.586sec
# Epoch 255 tr: l 0.198 a 0.941 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.121sec(train) 41.681sec(infer)
# Epoch 255 tst: l 0.211 a 0.940 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  6.587sec
# Epoch 256 tr: l 0.197 a 0.941 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.661sec(train) 47.427sec(infer)
# Epoch 256 tst: l 0.211 a 0.940 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  5.538sec
# Epoch 257 tr: l 0.197 a 0.941 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.743sec(train) 51.678sec(infer)
# Epoch 257 tst: l 0.210 a 0.940 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.043sec
# Epoch 258 tr: l 0.197 a 0.941 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.859sec(train) 46.355sec(infer)
# Epoch 258 tst: l 0.210 a 0.940 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  10.064sec
# Epoch 259 tr: l 0.196 a 0.941 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.259sec(train) 39.754sec(infer)
# Epoch 259 tst: l 0.209 a 0.940 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.497sec
# Epoch 260 tr: l 0.196 a 0.941 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.133sec(train) 45.575sec(infer)
# Epoch 260 tst: l 0.209 a 0.940 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.154sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 261 tr: l 0.195 a 0.941 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.526sec(train) 48.675sec(infer)
# Epoch 261 tst: l 0.208 a 0.941 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  10.484sec
# Epoch 262 tr: l 0.195 a 0.941 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.075sec(train) 47.108sec(infer)
# Epoch 262 tst: l 0.208 a 0.941 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  6.941sec
# Epoch 263 tr: l 0.194 a 0.942 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.603sec(train) 44.543sec(infer)
# Epoch 263 tst: l 0.208 a 0.941 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.011sec
# Epoch 264 tr: l 0.194 a 0.942 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.648sec(train) 48.968sec(infer)
# Epoch 264 tst: l 0.207 a 0.941 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  5.601sec
# Epoch 265 tr: l 0.193 a 0.942 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.416sec(train) 49.159sec(infer)
# Epoch 265 tst: l 0.207 a 0.941 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  5.175sec
# Epoch 266 tr: l 0.193 a 0.942 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.016sec(train) 44.107sec(infer)
# Epoch 266 tst: l 0.206 a 0.941 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.163sec
# Epoch 267 tr: l 0.192 a 0.942 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.874sec(train) 45.138sec(infer)
# Epoch 267 tst: l 0.206 a 0.941 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.434sec
# Epoch 268 tr: l 0.192 a 0.942 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.430sec(train) 50.481sec(infer)
# Epoch 268 tst: l 0.206 a 0.941 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  5.267sec
# Epoch 269 tr: l 0.191 a 0.942 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.708sec(train) 44.660sec(infer)
# Epoch 269 tst: l 0.205 a 0.941 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  9.197sec
# Epoch 270 tr: l 0.191 a 0.942 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.919sec(train) 42.279sec(infer)
# Epoch 270 tst: l 0.205 a 0.942 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.061sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 271 tr: l 0.190 a 0.943 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.387sec(train) 46.958sec(infer)
# Epoch 271 tst: l 0.204 a 0.942 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.217sec
# Epoch 272 tr: l 0.190 a 0.943 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.817sec(train) 45.005sec(infer)
# Epoch 272 tst: l 0.204 a 0.942 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  10.658sec
# Epoch 273 tr: l 0.190 a 0.943 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.293sec(train) 44.629sec(infer)
# Epoch 273 tst: l 0.204 a 0.942 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.008sec
# Epoch 274 tr: l 0.189 a 0.943 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.109sec(train) 44.104sec(infer)
# Epoch 274 tst: l 0.203 a 0.942 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.804sec
# Epoch 275 tr: l 0.189 a 0.943 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.486sec(train) 48.103sec(infer)
# Epoch 275 tst: l 0.203 a 0.942 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.113sec
# Epoch 276 tr: l 0.188 a 0.943 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.650sec(train) 49.197sec(infer)
# Epoch 276 tst: l 0.202 a 0.942 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  6.634sec
# Epoch 277 tr: l 0.188 a 0.943 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.806sec(train) 44.931sec(infer)
# Epoch 277 tst: l 0.202 a 0.942 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  5.949sec
# Epoch 278 tr: l 0.187 a 0.943 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.711sec(train) 47.173sec(infer)
# Epoch 278 tst: l 0.202 a 0.942 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  5.563sec
# Epoch 279 tr: l 0.187 a 0.943 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.932sec(train) 48.418sec(infer)
# Epoch 279 tst: l 0.201 a 0.943 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.963sec
# Epoch 280 tr: l 0.186 a 0.944 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.602sec(train) 45.690sec(infer)
# Epoch 280 tst: l 0.201 a 0.943 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.929sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 281 tr: l 0.186 a 0.944 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.033sec(train) 42.633sec(infer)
# Epoch 281 tst: l 0.200 a 0.943 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  9.519sec
# Epoch 282 tr: l 0.186 a 0.944 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.443sec(train) 46.063sec(infer)
# Epoch 282 tst: l 0.200 a 0.943 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.736sec
# Epoch 283 tr: l 0.185 a 0.944 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.849sec(train) 51.211sec(infer)
# Epoch 283 tst: l 0.200 a 0.943 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.268sec
# Epoch 284 tr: l 0.185 a 0.944 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.351sec(train) 48.140sec(infer)
# Epoch 284 tst: l 0.199 a 0.943 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.581sec
# Epoch 285 tr: l 0.184 a 0.944 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.902sec(train) 42.370sec(infer)
# Epoch 285 tst: l 0.199 a 0.943 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.476sec
# Epoch 286 tr: l 0.184 a 0.944 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.635sec(train) 44.729sec(infer)
# Epoch 286 tst: l 0.199 a 0.943 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  6.855sec
# Epoch 287 tr: l 0.184 a 0.944 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.237sec(train) 49.510sec(infer)
# Epoch 287 tst: l 0.198 a 0.943 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.865sec
# Epoch 288 tr: l 0.183 a 0.944 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.192sec(train) 47.094sec(infer)
# Epoch 288 tst: l 0.198 a 0.944 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  9.935sec
# Epoch 289 tr: l 0.183 a 0.945 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.087sec(train) 42.051sec(infer)
# Epoch 289 tst: l 0.197 a 0.944 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.405sec
# Epoch 290 tr: l 0.182 a 0.945 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.814sec(train) 45.306sec(infer)
# Epoch 290 tst: l 0.197 a 0.944 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  6.560sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# Epoch 291 tr: l 0.182 a 0.945 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.175sec(train) 47.687sec(infer)
# Epoch 291 tst: l 0.197 a 0.944 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  6.168sec
# Epoch 292 tr: l 0.181 a 0.945 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.221sec(train) 48.242sec(infer)
# Epoch 292 tst: l 0.196 a 0.944 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  5.909sec
# Epoch 293 tr: l 0.181 a 0.945 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 25.098sec(train) 44.269sec(infer)
# Epoch 293 tst: l 0.196 a 0.944 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.823sec
# Epoch 294 tr: l 0.181 a 0.945 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.388sec(train) 45.506sec(infer)
# Epoch 294 tst: l 0.196 a 0.944 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.162sec
# Epoch 295 tr: l 0.180 a 0.945 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.305sec(train) 47.933sec(infer)
# Epoch 295 tst: l 0.195 a 0.944 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.011sec
# Epoch 296 tr: l 0.180 a 0.945 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.915sec(train) 45.252sec(infer)
# Epoch 296 tst: l 0.195 a 0.945 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  8.194sec
# Epoch 297 tr: l 0.179 a 0.945 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 22.758sec(train) 45.330sec(infer)
# Epoch 297 tst: l 0.195 a 0.945 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  7.031sec
# Epoch 298 tr: l 0.179 a 0.946 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 24.255sec(train) 44.870sec(infer)
# Epoch 298 tst: l 0.194 a 0.945 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  9.122sec
# Epoch 299 tr: l 0.179 a 0.946 clct[np.int64(9), np.int64(300), np.int64(298), np.int64(593)] cl_acc 0.754  lr 0.100000 23.849sec(train) 43.557sec(infer)
# Epoch 299 tst: l 0.194 a 0.945 clct[np.int64(0), np.int64(50), np.int64(50), np.int64(100)] cl_acc 0.750  9.887sec
# result written at output_ifca/results.pickle
# checkpoint written at output_ifca/checkpoint.pt
# ---train cluster Ended in 4.82 hour (17346.817 sec)

# %% [markdown]
# DFCA-LI Experiment Outputs

# %%
__.display_outputs()
# Out:
# ---------------------------------DFCA-LI, lr: 0.1, seed: 1824---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': True, 'h1': 200, 'num_epochs': 300, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_li'}
# Using device: cuda:0
# Epoch -1 tr: l 2.294 a 0.118 clct[np.int64(306), np.int64(277), np.int64(298), np.int64(319)] cl_acc 0.275  25.276sec
# Epoch -1 tst: l 2.294 a 0.136 clct[np.int64(45), np.int64(49), np.int64(50), np.int64(56)] cl_acc 0.335  17.061sec
# Epoch 0 tr: l 2.238 a 0.306 clct[np.int64(269), np.int64(377), np.int64(282), np.int64(272)] cl_acc 0.284  lr 0.100000 28.649sec(train) 23.797sec(infer)
# Epoch 0 tst: l 2.281 a 0.263 clct[np.int64(53), np.int64(57), np.int64(45), np.int64(45)] cl_acc 0.315  17.288sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 1 tr: l 2.257 a 0.252 clct[np.int64(276), np.int64(232), np.int64(344), np.int64(348)] cl_acc 0.283  lr 0.100000 27.840sec(train) 24.090sec(infer)
# Epoch 1 tst: l 2.283 a 0.250 clct[np.int64(50), np.int64(37), np.int64(57), np.int64(56)] cl_acc 0.330  17.378sec
# Epoch 2 tr: l 2.262 a 0.183 clct[np.int64(310), np.int64(398), np.int64(328), np.int64(164)] cl_acc 0.299  lr 0.100000 28.550sec(train) 24.473sec(infer)
# Epoch 2 tst: l 2.281 a 0.199 clct[np.int64(52), np.int64(63), np.int64(57), np.int64(28)] cl_acc 0.350  16.869sec
# Epoch 3 tr: l 2.251 a 0.143 clct[np.int64(370), np.int64(261), np.int64(377), np.int64(192)] cl_acc 0.333  lr 0.100000 28.160sec(train) 23.998sec(infer)
# Epoch 3 tst: l 2.274 a 0.166 clct[np.int64(49), np.int64(45), np.int64(66), np.int64(40)] cl_acc 0.300  17.324sec
# Epoch 4 tr: l 2.236 a 0.134 clct[np.int64(491), np.int64(208), np.int64(346), np.int64(155)] cl_acc 0.380  lr 0.100000 28.624sec(train) 24.454sec(infer)
# Epoch 4 tst: l 2.256 a 0.166 clct[np.int64(87), np.int64(33), np.int64(54), np.int64(26)] cl_acc 0.350  16.838sec
# Epoch 5 tr: l 2.198 a 0.164 clct[np.int64(561), np.int64(180), np.int64(328), np.int64(131)] cl_acc 0.446  lr 0.100000 27.774sec(train) 24.365sec(infer)
# Epoch 5 tst: l 2.223 a 0.186 clct[np.int64(111), np.int64(30), np.int64(48), np.int64(11)] cl_acc 0.460  16.637sec
# Epoch 6 tr: l 2.148 a 0.237 clct[np.int64(604), np.int64(178), np.int64(315), np.int64(103)] cl_acc 0.539  lr 0.100000 24.887sec(train) 22.842sec(infer)
# Epoch 6 tst: l 2.174 a 0.242 clct[np.int64(112), np.int64(33), np.int64(50), np.int64(5)] cl_acc 0.545  17.613sec
# Epoch 7 tr: l 2.076 a 0.327 clct[np.int64(509), np.int64(292), np.int64(296), np.int64(103)] cl_acc 0.655  lr 0.100000 26.965sec(train) 26.066sec(infer)
# Epoch 7 tst: l 2.107 a 0.325 clct[np.int64(94), np.int64(53), np.int64(46), np.int64(7)] cl_acc 0.635  18.339sec
# Epoch 8 tr: l 1.960 a 0.421 clct[np.int64(347), np.int64(461), np.int64(295), np.int64(97)] cl_acc 0.744  lr 0.100000 28.880sec(train) 26.128sec(infer)
# Epoch 8 tst: l 2.000 a 0.409 clct[np.int64(59), np.int64(83), np.int64(48), np.int64(10)] cl_acc 0.715  18.616sec
# Epoch 9 tr: l 1.805 a 0.485 clct[np.int64(303), np.int64(514), np.int64(288), np.int64(95)] cl_acc 0.773  lr 0.100000 28.977sec(train) 24.887sec(infer)
# Epoch 9 tst: l 1.853 a 0.474 clct[np.int64(55), np.int64(87), np.int64(46), np.int64(12)] cl_acc 0.740  19.454sec
# Epoch 10 tr: l 1.648 a 0.532 clct[np.int64(290), np.int64(500), np.int64(292), np.int64(118)] cl_acc 0.812  lr 0.100000 23.521sec(train) 6.216sec(infer)
# Epoch 10 tst: l 1.692 a 0.524 clct[np.int64(50), np.int64(83), np.int64(48), np.int64(19)] cl_acc 0.825  4.276sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 11 tr: l 1.495 a 0.575 clct[np.int64(295), np.int64(429), np.int64(298), np.int64(178)] cl_acc 0.882  lr 0.100000 24.633sec(train) 6.078sec(infer)
# Epoch 11 tst: l 1.538 a 0.563 clct[np.int64(50), np.int64(72), np.int64(50), np.int64(28)] cl_acc 0.890  4.061sec
# Epoch 12 tr: l 1.343 a 0.625 clct[np.int64(298), np.int64(368), np.int64(300), np.int64(234)] cl_acc 0.938  lr 0.100000 23.249sec(train) 10.169sec(infer)
# Epoch 12 tst: l 1.378 a 0.609 clct[np.int64(50), np.int64(57), np.int64(50), np.int64(43)] cl_acc 0.965  15.475sec
# Epoch 13 tr: l 1.197 a 0.669 clct[np.int64(300), np.int64(323), np.int64(301), np.int64(276)] cl_acc 0.978  lr 0.100000 27.752sec(train) 25.839sec(infer)
# Epoch 13 tst: l 1.235 a 0.652 clct[np.int64(50), np.int64(52), np.int64(50), np.int64(48)] cl_acc 0.990  18.318sec
# Epoch 14 tr: l 1.074 a 0.712 clct[np.int64(300), np.int64(305), np.int64(302), np.int64(293)] cl_acc 0.993  lr 0.100000 28.931sec(train) 24.959sec(infer)
# Epoch 14 tst: l 1.104 a 0.697 clct[np.int64(50), np.int64(51), np.int64(50), np.int64(49)] cl_acc 0.995  19.129sec
# Epoch 15 tr: l 0.966 a 0.745 clct[np.int64(300), np.int64(300), np.int64(301), np.int64(299)] cl_acc 0.999  lr 0.100000 29.270sec(train) 26.128sec(infer)
# Epoch 15 tst: l 0.993 a 0.731 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.636sec
# Epoch 16 tr: l 0.875 a 0.770 clct[np.int64(300), np.int64(300), np.int64(301), np.int64(299)] cl_acc 0.999  lr 0.100000 28.974sec(train) 26.840sec(infer)
# Epoch 16 tst: l 0.906 a 0.755 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.577sec
# Epoch 17 tr: l 0.799 a 0.787 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.088sec(train) 26.043sec(infer)
# Epoch 17 tst: l 0.825 a 0.775 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.565sec
# Epoch 18 tr: l 0.736 a 0.803 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.666sec(train) 27.311sec(infer)
# Epoch 18 tst: l 0.760 a 0.793 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.377sec
# Epoch 19 tr: l 0.688 a 0.813 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.682sec(train) 26.228sec(infer)
# Epoch 19 tst: l 0.712 a 0.803 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.473sec
# Epoch 20 tr: l 0.645 a 0.824 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.393sec(train) 25.620sec(infer)
# Epoch 20 tst: l 0.667 a 0.815 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.309sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 21 tr: l 0.612 a 0.832 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.832sec(train) 26.545sec(infer)
# Epoch 21 tst: l 0.632 a 0.823 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.032sec
# Epoch 22 tr: l 0.579 a 0.840 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.419sec(train) 25.319sec(infer)
# Epoch 22 tst: l 0.598 a 0.831 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.115sec
# Epoch 23 tr: l 0.550 a 0.848 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.715sec(train) 24.643sec(infer)
# Epoch 23 tst: l 0.575 a 0.838 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.112sec
# Epoch 24 tr: l 0.532 a 0.853 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.425sec(train) 25.536sec(infer)
# Epoch 24 tst: l 0.550 a 0.843 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.115sec
# Epoch 25 tr: l 0.511 a 0.858 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.705sec(train) 24.629sec(infer)
# Epoch 25 tst: l 0.530 a 0.849 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.974sec
# Epoch 26 tr: l 0.490 a 0.863 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.108sec(train) 24.437sec(infer)
# Epoch 26 tst: l 0.513 a 0.853 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.996sec
# Epoch 27 tr: l 0.476 a 0.868 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.263sec(train) 25.635sec(infer)
# Epoch 27 tst: l 0.496 a 0.859 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.214sec
# Epoch 28 tr: l 0.461 a 0.871 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.689sec(train) 24.886sec(infer)
# Epoch 28 tst: l 0.482 a 0.863 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.756sec
# Epoch 29 tr: l 0.454 a 0.873 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.228sec(train) 25.684sec(infer)
# Epoch 29 tst: l 0.469 a 0.867 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.716sec
# Epoch 30 tr: l 0.441 a 0.876 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.158sec(train) 26.414sec(infer)
# Epoch 30 tst: l 0.458 a 0.869 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.676sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 31 tr: l 0.429 a 0.878 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.384sec(train) 25.362sec(infer)
# Epoch 31 tst: l 0.448 a 0.871 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.286sec
# Epoch 32 tr: l 0.421 a 0.882 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.046sec(train) 26.754sec(infer)
# Epoch 32 tst: l 0.437 a 0.875 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.319sec
# Epoch 33 tr: l 0.411 a 0.884 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.182sec(train) 26.499sec(infer)
# Epoch 33 tst: l 0.429 a 0.878 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.902sec
# Epoch 34 tr: l 0.401 a 0.886 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.244sec(train) 25.725sec(infer)
# Epoch 34 tst: l 0.421 a 0.880 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.221sec
# Epoch 35 tr: l 0.394 a 0.887 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 25.780sec(train) 24.600sec(infer)
# Epoch 35 tst: l 0.413 a 0.882 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.007sec
# Epoch 36 tr: l 0.389 a 0.889 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.331sec(train) 25.303sec(infer)
# Epoch 36 tst: l 0.407 a 0.884 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.363sec
# Epoch 37 tr: l 0.381 a 0.892 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.581sec(train) 24.571sec(infer)
# Epoch 37 tst: l 0.399 a 0.885 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.961sec
# Epoch 38 tr: l 0.374 a 0.893 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.558sec(train) 24.398sec(infer)
# Epoch 38 tst: l 0.396 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.112sec
# Epoch 39 tr: l 0.369 a 0.894 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.519sec(train) 25.119sec(infer)
# Epoch 39 tst: l 0.387 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.288sec
# Epoch 40 tr: l 0.363 a 0.896 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.809sec(train) 24.757sec(infer)
# Epoch 40 tst: l 0.383 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.642sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 41 tr: l 0.358 a 0.897 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.323sec(train) 24.474sec(infer)
# Epoch 41 tst: l 0.378 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.744sec
# Epoch 42 tr: l 0.353 a 0.898 clct[np.int64(300), np.int64(299), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 28.152sec(train) 25.584sec(infer)
# Epoch 42 tst: l 0.375 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.711sec
# Epoch 43 tr: l 0.348 a 0.899 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.918sec(train) 25.148sec(infer)
# Epoch 43 tst: l 0.372 a 0.892 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.643sec
# Epoch 44 tr: l 0.346 a 0.900 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.451sec(train) 24.856sec(infer)
# Epoch 44 tst: l 0.367 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.728sec
# Epoch 45 tr: l 0.339 a 0.902 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.840sec(train) 26.158sec(infer)
# Epoch 45 tst: l 0.363 a 0.894 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.251sec
# Epoch 46 tr: l 0.338 a 0.902 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.930sec(train) 25.841sec(infer)
# Epoch 46 tst: l 0.359 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.185sec
# Epoch 47 tr: l 0.335 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.019sec(train) 25.402sec(infer)
# Epoch 47 tst: l 0.355 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.019sec
# Epoch 48 tr: l 0.331 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.015sec(train) 26.775sec(infer)
# Epoch 48 tst: l 0.352 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.421sec
# Epoch 49 tr: l 0.326 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.920sec(train) 26.534sec(infer)
# Epoch 49 tst: l 0.350 a 0.897 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.356sec
# Epoch 50 tr: l 0.324 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.479sec(train) 25.846sec(infer)
# Epoch 50 tst: l 0.347 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.248sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 51 tr: l 0.321 a 0.906 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.760sec(train) 26.626sec(infer)
# Epoch 51 tst: l 0.344 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.424sec
# Epoch 52 tr: l 0.318 a 0.907 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.771sec(train) 26.281sec(infer)
# Epoch 52 tst: l 0.341 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.060sec
# Epoch 53 tr: l 0.320 a 0.906 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.584sec(train) 24.972sec(infer)
# Epoch 53 tst: l 0.340 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.297sec
# Epoch 54 tr: l 0.316 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.179sec(train) 25.526sec(infer)
# Epoch 54 tst: l 0.338 a 0.900 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.622sec
# Epoch 55 tr: l 0.311 a 0.909 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.363sec(train) 25.160sec(infer)
# Epoch 55 tst: l 0.336 a 0.901 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.153sec
# Epoch 56 tr: l 0.314 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.552sec(train) 24.070sec(infer)
# Epoch 56 tst: l 0.333 a 0.902 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.552sec
# Epoch 57 tr: l 0.308 a 0.909 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.513sec(train) 20.024sec(infer)
# Epoch 57 tst: l 0.333 a 0.902 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.512sec
# Epoch 58 tr: l 0.305 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.545sec(train) 25.572sec(infer)
# Epoch 58 tst: l 0.330 a 0.903 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.043sec
# Epoch 59 tr: l 0.304 a 0.911 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.668sec(train) 24.365sec(infer)
# Epoch 59 tst: l 0.327 a 0.903 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.964sec
# Epoch 60 tr: l 0.302 a 0.911 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.545sec(train) 24.872sec(infer)
# Epoch 60 tst: l 0.326 a 0.903 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.063sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 61 tr: l 0.301 a 0.912 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.821sec(train) 25.812sec(infer)
# Epoch 61 tst: l 0.324 a 0.904 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.581sec
# Epoch 62 tr: l 0.295 a 0.913 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.632sec(train) 24.751sec(infer)
# Epoch 62 tst: l 0.322 a 0.904 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.099sec
# Epoch 63 tr: l 0.297 a 0.913 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.769sec(train) 26.004sec(infer)
# Epoch 63 tst: l 0.322 a 0.904 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.592sec
# Epoch 64 tr: l 0.294 a 0.914 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.632sec(train) 26.865sec(infer)
# Epoch 64 tst: l 0.320 a 0.904 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.979sec
# Epoch 65 tr: l 0.292 a 0.914 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.977sec(train) 26.944sec(infer)
# Epoch 65 tst: l 0.319 a 0.905 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.701sec
# Epoch 66 tr: l 0.289 a 0.914 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.352sec(train) 26.718sec(infer)
# Epoch 66 tst: l 0.316 a 0.906 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.759sec
# Epoch 67 tr: l 0.288 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.861sec(train) 27.110sec(infer)
# Epoch 67 tst: l 0.315 a 0.906 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.111sec
# Epoch 68 tr: l 0.288 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.869sec(train) 25.306sec(infer)
# Epoch 68 tst: l 0.315 a 0.906 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.768sec
# Epoch 69 tr: l 0.288 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.354sec(train) 25.469sec(infer)
# Epoch 69 tst: l 0.313 a 0.907 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.211sec
# Epoch 70 tr: l 0.285 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.235sec(train) 26.547sec(infer)
# Epoch 70 tst: l 0.312 a 0.908 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.701sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 71 tr: l 0.287 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.358sec(train) 25.388sec(infer)
# Epoch 71 tst: l 0.310 a 0.908 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.401sec
# Epoch 72 tr: l 0.280 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.351sec(train) 25.492sec(infer)
# Epoch 72 tst: l 0.309 a 0.908 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.092sec
# Epoch 73 tr: l 0.282 a 0.916 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.045sec(train) 26.589sec(infer)
# Epoch 73 tst: l 0.307 a 0.909 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.242sec
# Epoch 74 tr: l 0.277 a 0.917 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.791sec(train) 25.680sec(infer)
# Epoch 74 tst: l 0.307 a 0.909 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.273sec
# Epoch 75 tr: l 0.282 a 0.917 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.291sec(train) 26.190sec(infer)
# Epoch 75 tst: l 0.306 a 0.909 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.840sec
# Epoch 76 tr: l 0.280 a 0.916 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.899sec(train) 27.229sec(infer)
# Epoch 76 tst: l 0.305 a 0.910 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.756sec
# Epoch 77 tr: l 0.277 a 0.917 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.300sec(train) 25.690sec(infer)
# Epoch 77 tst: l 0.303 a 0.910 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.742sec
# Epoch 78 tr: l 0.273 a 0.918 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.112sec(train) 26.593sec(infer)
# Epoch 78 tst: l 0.303 a 0.910 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.209sec
# Epoch 79 tr: l 0.275 a 0.918 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.507sec(train) 27.217sec(infer)
# Epoch 79 tst: l 0.301 a 0.911 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.479sec
# Epoch 80 tr: l 0.273 a 0.918 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.474sec(train) 26.302sec(infer)
# Epoch 80 tst: l 0.300 a 0.911 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.095sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 81 tr: l 0.275 a 0.919 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.973sec(train) 27.664sec(infer)
# Epoch 81 tst: l 0.299 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.058sec
# Epoch 82 tr: l 0.274 a 0.918 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.248sec(train) 26.246sec(infer)
# Epoch 82 tst: l 0.299 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.510sec
# Epoch 83 tr: l 0.273 a 0.919 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.299sec(train) 25.918sec(infer)
# Epoch 83 tst: l 0.297 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.150sec
# Epoch 84 tr: l 0.271 a 0.919 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.552sec(train) 26.358sec(infer)
# Epoch 84 tst: l 0.297 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.915sec
# Epoch 85 tr: l 0.269 a 0.920 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.022sec(train) 24.905sec(infer)
# Epoch 85 tst: l 0.297 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.380sec
# Epoch 86 tr: l 0.268 a 0.920 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.638sec(train) 24.343sec(infer)
# Epoch 86 tst: l 0.294 a 0.913 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.316sec
# Epoch 87 tr: l 0.267 a 0.920 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.882sec(train) 25.094sec(infer)
# Epoch 87 tst: l 0.295 a 0.913 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.749sec
# Epoch 88 tr: l 0.264 a 0.921 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.612sec(train) 26.675sec(infer)
# Epoch 88 tst: l 0.294 a 0.913 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.174sec
# Epoch 89 tr: l 0.264 a 0.920 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.157sec(train) 25.635sec(infer)
# Epoch 89 tst: l 0.292 a 0.914 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.367sec
# Epoch 90 tr: l 0.264 a 0.921 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.316sec(train) 25.994sec(infer)
# Epoch 90 tst: l 0.292 a 0.914 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.565sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 91 tr: l 0.259 a 0.922 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.862sec(train) 26.375sec(infer)
# Epoch 91 tst: l 0.290 a 0.914 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.220sec
# Epoch 92 tr: l 0.261 a 0.922 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.436sec(train) 24.986sec(infer)
# Epoch 92 tst: l 0.290 a 0.914 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.154sec
# Epoch 93 tr: l 0.260 a 0.922 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.360sec(train) 25.771sec(infer)
# Epoch 93 tst: l 0.289 a 0.914 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.418sec
# Epoch 94 tr: l 0.259 a 0.922 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.109sec(train) 27.173sec(infer)
# Epoch 94 tst: l 0.288 a 0.915 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.434sec
# Epoch 95 tr: l 0.260 a 0.923 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.322sec(train) 26.558sec(infer)
# Epoch 95 tst: l 0.288 a 0.914 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.879sec
# Epoch 96 tr: l 0.255 a 0.923 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.130sec(train) 26.401sec(infer)
# Epoch 96 tst: l 0.287 a 0.915 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.056sec
# Epoch 97 tr: l 0.258 a 0.923 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.591sec(train) 24.808sec(infer)
# Epoch 97 tst: l 0.286 a 0.915 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.902sec
# Epoch 98 tr: l 0.257 a 0.923 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.858sec(train) 24.833sec(infer)
# Epoch 98 tst: l 0.285 a 0.915 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.909sec
# Epoch 99 tr: l 0.254 a 0.924 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.743sec(train) 25.300sec(infer)
# Epoch 99 tst: l 0.285 a 0.915 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.435sec
# Epoch 100 tr: l 0.255 a 0.924 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.938sec(train) 24.283sec(infer)
# Epoch 100 tst: l 0.284 a 0.916 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.161sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 101 tr: l 0.255 a 0.924 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.252sec(train) 24.716sec(infer)
# Epoch 101 tst: l 0.283 a 0.916 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.843sec
# Epoch 102 tr: l 0.252 a 0.924 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.294sec(train) 19.689sec(infer)
# Epoch 102 tst: l 0.282 a 0.917 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.558sec
# Epoch 103 tr: l 0.249 a 0.925 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.814sec(train) 24.506sec(infer)
# Epoch 103 tst: l 0.282 a 0.916 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.928sec
# Epoch 104 tr: l 0.248 a 0.925 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.591sec(train) 24.917sec(infer)
# Epoch 104 tst: l 0.280 a 0.917 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.346sec
# Epoch 105 tr: l 0.247 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.632sec(train) 26.577sec(infer)
# Epoch 105 tst: l 0.280 a 0.917 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.215sec
# Epoch 106 tr: l 0.250 a 0.925 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.214sec(train) 25.569sec(infer)
# Epoch 106 tst: l 0.279 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.626sec
# Epoch 107 tr: l 0.248 a 0.925 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.123sec(train) 26.108sec(infer)
# Epoch 107 tst: l 0.278 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.609sec
# Epoch 108 tr: l 0.249 a 0.925 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.254sec(train) 26.779sec(infer)
# Epoch 108 tst: l 0.278 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.510sec
# Epoch 109 tr: l 0.244 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.593sec(train) 25.524sec(infer)
# Epoch 109 tst: l 0.277 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.094sec
# Epoch 110 tr: l 0.248 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.515sec(train) 26.809sec(infer)
# Epoch 110 tst: l 0.277 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.621sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 111 tr: l 0.243 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 23.935sec(train) 28.073sec(infer)
# Epoch 111 tst: l 0.275 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.081sec
# Epoch 112 tr: l 0.244 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.286sec(train) 25.758sec(infer)
# Epoch 112 tst: l 0.276 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.724sec
# Epoch 113 tr: l 0.243 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.095sec(train) 26.004sec(infer)
# Epoch 113 tst: l 0.275 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.902sec
# Epoch 114 tr: l 0.243 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.332sec(train) 26.371sec(infer)
# Epoch 114 tst: l 0.274 a 0.919 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.055sec
# Epoch 115 tr: l 0.243 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.251sec(train) 24.479sec(infer)
# Epoch 115 tst: l 0.274 a 0.919 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.948sec
# Epoch 116 tr: l 0.241 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.443sec(train) 25.055sec(infer)
# Epoch 116 tst: l 0.274 a 0.919 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.469sec
# Epoch 117 tr: l 0.239 a 0.928 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 22.792sec(train) 26.390sec(infer)
# Epoch 117 tst: l 0.273 a 0.919 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.625sec
# Epoch 118 tr: l 0.239 a 0.928 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.085sec(train) 26.413sec(infer)
# Epoch 118 tst: l 0.271 a 0.919 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.644sec
# Epoch 119 tr: l 0.238 a 0.928 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.192sec(train) 25.576sec(infer)
# Epoch 119 tst: l 0.271 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.921sec
# Epoch 120 tr: l 0.237 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.052sec(train) 26.675sec(infer)
# Epoch 120 tst: l 0.270 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.190sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 121 tr: l 0.234 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.988sec(train) 26.293sec(infer)
# Epoch 121 tst: l 0.270 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.730sec
# Epoch 122 tr: l 0.234 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.323sec(train) 25.361sec(infer)
# Epoch 122 tst: l 0.270 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.231sec
# Epoch 123 tr: l 0.235 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.792sec(train) 28.220sec(infer)
# Epoch 123 tst: l 0.268 a 0.921 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.047sec
# Epoch 124 tr: l 0.230 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.813sec(train) 27.007sec(infer)
# Epoch 124 tst: l 0.268 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.298sec
# Epoch 125 tr: l 0.233 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.663sec(train) 25.827sec(infer)
# Epoch 125 tst: l 0.267 a 0.921 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.259sec
# Epoch 126 tr: l 0.232 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.252sec(train) 26.150sec(infer)
# Epoch 126 tst: l 0.267 a 0.921 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.263sec
# Epoch 127 tr: l 0.235 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.973sec(train) 25.711sec(infer)
# Epoch 127 tst: l 0.267 a 0.921 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.650sec
# Epoch 128 tr: l 0.234 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.646sec(train) 24.910sec(infer)
# Epoch 128 tst: l 0.265 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.065sec
# Epoch 129 tr: l 0.231 a 0.931 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.093sec(train) 25.996sec(infer)
# Epoch 129 tst: l 0.265 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.087sec
# Epoch 130 tr: l 0.233 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.754sec(train) 25.929sec(infer)
# Epoch 130 tst: l 0.264 a 0.921 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.424sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 131 tr: l 0.230 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.607sec(train) 25.523sec(infer)
# Epoch 131 tst: l 0.264 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.237sec
# Epoch 132 tr: l 0.230 a 0.931 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.668sec(train) 27.113sec(infer)
# Epoch 132 tst: l 0.264 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.264sec
# Epoch 133 tr: l 0.228 a 0.931 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.720sec(train) 25.406sec(infer)
# Epoch 133 tst: l 0.263 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.837sec
# Epoch 134 tr: l 0.229 a 0.931 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.208sec(train) 26.159sec(infer)
# Epoch 134 tst: l 0.262 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.586sec
# Epoch 135 tr: l 0.227 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.088sec(train) 26.818sec(infer)
# Epoch 135 tst: l 0.261 a 0.923 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.694sec
# Epoch 136 tr: l 0.229 a 0.931 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.390sec(train) 25.508sec(infer)
# Epoch 136 tst: l 0.261 a 0.923 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.963sec
# Epoch 137 tr: l 0.225 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.001sec(train) 27.017sec(infer)
# Epoch 137 tst: l 0.260 a 0.923 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.643sec
# Epoch 138 tr: l 0.224 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.864sec(train) 27.160sec(infer)
# Epoch 138 tst: l 0.260 a 0.923 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.957sec
# Epoch 139 tr: l 0.226 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.414sec(train) 26.392sec(infer)
# Epoch 139 tst: l 0.259 a 0.923 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.080sec
# Epoch 140 tr: l 0.226 a 0.931 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.079sec(train) 26.941sec(infer)
# Epoch 140 tst: l 0.258 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.958sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 141 tr: l 0.227 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.444sec(train) 24.793sec(infer)
# Epoch 141 tst: l 0.258 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.094sec
# Epoch 142 tr: l 0.223 a 0.933 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.350sec(train) 25.566sec(infer)
# Epoch 142 tst: l 0.258 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.886sec
# Epoch 143 tr: l 0.223 a 0.933 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.457sec(train) 25.791sec(infer)
# Epoch 143 tst: l 0.257 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.079sec
# Epoch 144 tr: l 0.215 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.437sec(train) 24.112sec(infer)
# Epoch 144 tst: l 0.256 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.160sec
# Epoch 145 tr: l 0.223 a 0.933 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.655sec(train) 24.684sec(infer)
# Epoch 145 tst: l 0.256 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.374sec
# Epoch 146 tr: l 0.219 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.247sec(train) 25.487sec(infer)
# Epoch 146 tst: l 0.255 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.878sec
# Epoch 147 tr: l 0.223 a 0.933 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.459sec(train) 19.775sec(infer)
# Epoch 147 tst: l 0.254 a 0.925 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.312sec
# Epoch 148 tr: l 0.218 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.062sec(train) 24.951sec(infer)
# Epoch 148 tst: l 0.254 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.169sec
# Epoch 149 tr: l 0.220 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.101sec(train) 25.982sec(infer)
# Epoch 149 tst: l 0.255 a 0.925 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.303sec
# Epoch 150 tr: l 0.218 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.189sec(train) 25.072sec(infer)
# Epoch 150 tst: l 0.253 a 0.925 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.115sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 151 tr: l 0.215 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.126sec(train) 24.048sec(infer)
# Epoch 151 tst: l 0.252 a 0.925 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.846sec
# Epoch 152 tr: l 0.215 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.689sec(train) 23.869sec(infer)
# Epoch 152 tst: l 0.253 a 0.925 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.083sec
# Epoch 153 tr: l 0.216 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.749sec(train) 22.917sec(infer)
# Epoch 153 tst: l 0.251 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.334sec
# Epoch 154 tr: l 0.214 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.826sec(train) 22.980sec(infer)
# Epoch 154 tst: l 0.252 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.157sec
# Epoch 155 tr: l 0.215 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.093sec(train) 23.756sec(infer)
# Epoch 155 tst: l 0.251 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.240sec
# Epoch 156 tr: l 0.215 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.218sec(train) 23.471sec(infer)
# Epoch 156 tst: l 0.250 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  14.950sec
# Epoch 157 tr: l 0.212 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.915sec(train) 22.702sec(infer)
# Epoch 157 tst: l 0.249 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.224sec
# Epoch 158 tr: l 0.215 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.408sec(train) 23.760sec(infer)
# Epoch 158 tst: l 0.249 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.278sec
# Epoch 159 tr: l 0.212 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.863sec(train) 24.236sec(infer)
# Epoch 159 tst: l 0.248 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  14.940sec
# Epoch 160 tr: l 0.209 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.836sec(train) 22.982sec(infer)
# Epoch 160 tst: l 0.249 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.974sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 161 tr: l 0.211 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.955sec(train) 24.054sec(infer)
# Epoch 161 tst: l 0.247 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.583sec
# Epoch 162 tr: l 0.211 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.121sec(train) 24.706sec(infer)
# Epoch 162 tst: l 0.247 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.023sec
# Epoch 163 tr: l 0.210 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.954sec(train) 23.611sec(infer)
# Epoch 163 tst: l 0.246 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.996sec
# Epoch 164 tr: l 0.210 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.248sec(train) 24.538sec(infer)
# Epoch 164 tst: l 0.246 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.261sec
# Epoch 165 tr: l 0.209 a 0.937 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.094sec(train) 24.596sec(infer)
# Epoch 165 tst: l 0.245 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  14.905sec
# Epoch 166 tr: l 0.210 a 0.937 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.895sec(train) 23.787sec(infer)
# Epoch 166 tst: l 0.248 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.934sec
# Epoch 167 tr: l 0.208 a 0.937 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.129sec(train) 24.603sec(infer)
# Epoch 167 tst: l 0.245 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.090sec
# Epoch 168 tr: l 0.210 a 0.937 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.246sec(train) 24.461sec(infer)
# Epoch 168 tst: l 0.245 a 0.928 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  14.997sec
# ...
# Epoch 243 tr: l 0.172 a 0.948 clct[np.int64(299), np.int64(299), np.int64(301), np.int64(301)] cl_acc 0.998  lr 0.100000 20.268sec(train) 2.927sec(infer)
# Epoch 243 tst: l 0.225 a 0.937 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.918sec
# Epoch 244 tr: l 0.169 a 0.949 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 22.861sec(train) 2.924sec(infer)
# Epoch 244 tst: l 0.225 a 0.937 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.916sec
# Epoch 245 tr: l 0.171 a 0.948 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.559sec(train) 2.112sec(infer)
# Epoch 245 tst: l 0.224 a 0.937 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.886sec
# Epoch 246 tr: l 0.169 a 0.949 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.470sec(train) 2.938sec(infer)
# Epoch 246 tst: l 0.224 a 0.937 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.918sec
# Epoch 247 tr: l 0.171 a 0.949 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.394sec(train) 2.939sec(infer)
# Epoch 247 tst: l 0.222 a 0.938 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.925sec
# Epoch 248 tr: l 0.168 a 0.949 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.522sec(train) 2.919sec(infer)
# Epoch 248 tst: l 0.223 a 0.938 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.917sec
# Epoch 249 tr: l 0.168 a 0.949 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.450sec(train) 2.899sec(infer)
# Epoch 249 tst: l 0.222 a 0.937 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.884sec
# Epoch 250 tr: l 0.170 a 0.949 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.849sec(train) 2.933sec(infer)
# Epoch 250 tst: l 0.222 a 0.938 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.914sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 251 tr: l 0.168 a 0.949 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.584sec(train) 2.879sec(infer)
# Epoch 251 tst: l 0.222 a 0.938 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.919sec
# Epoch 252 tr: l 0.169 a 0.949 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.432sec(train) 2.874sec(infer)
# Epoch 252 tst: l 0.221 a 0.938 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.918sec
# Epoch 253 tr: l 0.168 a 0.949 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.430sec(train) 2.875sec(infer)
# Epoch 253 tst: l 0.221 a 0.938 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.917sec
# Epoch 254 tr: l 0.168 a 0.949 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.730sec(train) 2.858sec(infer)
# Epoch 254 tst: l 0.220 a 0.938 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.913sec
# Epoch 255 tr: l 0.165 a 0.950 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.417sec(train) 2.270sec(infer)
# Epoch 255 tst: l 0.220 a 0.938 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.916sec
# Epoch 256 tr: l 0.166 a 0.950 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.428sec(train) 2.853sec(infer)
# Epoch 256 tst: l 0.219 a 0.939 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.914sec
# Epoch 257 tr: l 0.166 a 0.950 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.524sec(train) 2.853sec(infer)
# Epoch 257 tst: l 0.220 a 0.938 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.916sec
# Epoch 258 tr: l 0.163 a 0.951 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.429sec(train) 2.824sec(infer)
# Epoch 258 tst: l 0.220 a 0.939 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.883sec
# Epoch 259 tr: l 0.166 a 0.950 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.631sec(train) 2.815sec(infer)
# Epoch 259 tst: l 0.218 a 0.939 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.885sec
# Epoch 260 tr: l 0.162 a 0.951 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.431sec(train) 2.851sec(infer)
# Epoch 260 tst: l 0.218 a 0.939 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.916sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 261 tr: l 0.162 a 0.951 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 24.830sec(train) 2.796sec(infer)
# Epoch 261 tst: l 0.218 a 0.939 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.888sec
# Epoch 262 tr: l 0.164 a 0.950 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 22.397sec(train) 2.852sec(infer)
# Epoch 262 tst: l 0.217 a 0.939 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.916sec
# Epoch 263 tr: l 0.165 a 0.950 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.040sec(train) 2.855sec(infer)
# Epoch 263 tst: l 0.219 a 0.939 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.921sec
# Epoch 264 tr: l 0.163 a 0.951 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.625sec(train) 2.850sec(infer)
# Epoch 264 tst: l 0.216 a 0.939 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.892sec
# Epoch 265 tr: l 0.163 a 0.950 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 24.812sec(train) 2.846sec(infer)
# Epoch 265 tst: l 0.216 a 0.939 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.910sec
# Epoch 266 tr: l 0.164 a 0.950 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.693sec(train) 2.798sec(infer)
# Epoch 266 tst: l 0.215 a 0.939 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.886sec
# Epoch 267 tr: l 0.159 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 22.962sec(train) 2.842sec(infer)
# Epoch 267 tst: l 0.215 a 0.940 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.920sec
# Epoch 268 tr: l 0.161 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.812sec(train) 2.787sec(infer)
# Epoch 268 tst: l 0.214 a 0.939 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.883sec
# Epoch 269 tr: l 0.160 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 24.182sec(train) 2.791sec(infer)
# Epoch 269 tst: l 0.214 a 0.940 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.883sec
# Epoch 270 tr: l 0.164 a 0.950 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 24.136sec(train) 2.837sec(infer)
# Epoch 270 tst: l 0.214 a 0.940 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  2.040sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 271 tr: l 0.157 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 21.439sec(train) 2.820sec(infer)
# Epoch 271 tst: l 0.215 a 0.940 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.968sec
# Epoch 272 tr: l 0.159 a 0.951 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 24.728sec(train) 2.771sec(infer)
# Epoch 272 tst: l 0.214 a 0.940 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  2.117sec
# Epoch 273 tr: l 0.159 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 22.215sec(train) 2.832sec(infer)
# Epoch 273 tst: l 0.214 a 0.940 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  2.143sec
# Epoch 274 tr: l 0.157 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 24.437sec(train) 3.157sec(infer)
# Epoch 274 tst: l 0.213 a 0.940 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  2.139sec
# Epoch 275 tr: l 0.161 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.463sec(train) 3.164sec(infer)
# Epoch 275 tst: l 0.212 a 0.940 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  2.139sec
# Epoch 276 tr: l 0.157 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 24.225sec(train) 3.162sec(infer)
# Epoch 276 tst: l 0.212 a 0.940 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  2.093sec
# Epoch 277 tr: l 0.157 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.571sec(train) 3.063sec(infer)
# Epoch 277 tst: l 0.212 a 0.940 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.946sec
# Epoch 278 tr: l 0.159 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 21.735sec(train) 3.158sec(infer)
# Epoch 278 tst: l 0.211 a 0.940 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.999sec
# Epoch 279 tr: l 0.158 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 21.617sec(train) 3.162sec(infer)
# Epoch 279 tst: l 0.211 a 0.941 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  2.100sec
# Epoch 280 tr: l 0.157 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 24.320sec(train) 3.082sec(infer)
# Epoch 280 tst: l 0.210 a 0.941 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.951sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 281 tr: l 0.160 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 24.218sec(train) 2.923sec(infer)
# Epoch 281 tst: l 0.210 a 0.941 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.919sec
# Epoch 282 tr: l 0.157 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.069sec(train) 2.905sec(infer)
# Epoch 282 tst: l 0.211 a 0.941 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.921sec
# Epoch 283 tr: l 0.155 a 0.953 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 22.740sec(train) 2.856sec(infer)
# Epoch 283 tst: l 0.211 a 0.941 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.918sec
# Epoch 284 tr: l 0.152 a 0.954 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.359sec(train) 1.962sec(infer)
# Epoch 284 tst: l 0.209 a 0.941 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.916sec
# Epoch 285 tr: l 0.158 a 0.952 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.623sec(train) 2.901sec(infer)
# Epoch 285 tst: l 0.209 a 0.941 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.919sec
# Epoch 286 tr: l 0.155 a 0.953 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.496sec(train) 2.838sec(infer)
# Epoch 286 tst: l 0.209 a 0.941 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.915sec
# Epoch 287 tr: l 0.155 a 0.953 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.746sec(train) 2.841sec(infer)
# Epoch 287 tst: l 0.209 a 0.941 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.910sec
# Epoch 288 tr: l 0.155 a 0.953 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 20.891sec(train) 2.922sec(infer)
# Epoch 288 tst: l 0.207 a 0.941 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.917sec
# Epoch 289 tr: l 0.153 a 0.954 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 24.556sec(train) 2.856sec(infer)
# Epoch 289 tst: l 0.208 a 0.942 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.915sec
# Epoch 290 tr: l 0.154 a 0.953 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 22.978sec(train) 2.837sec(infer)
# Epoch 290 tst: l 0.207 a 0.942 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.913sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# Epoch 291 tr: l 0.155 a 0.953 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 24.069sec(train) 2.819sec(infer)
# Epoch 291 tst: l 0.207 a 0.941 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.884sec
# Epoch 292 tr: l 0.155 a 0.953 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.809sec(train) 2.835sec(infer)
# Epoch 292 tst: l 0.208 a 0.942 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.918sec
# Epoch 293 tr: l 0.153 a 0.953 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 24.114sec(train) 2.833sec(infer)
# Epoch 293 tst: l 0.206 a 0.942 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.924sec
# Epoch 294 tr: l 0.152 a 0.954 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 22.729sec(train) 2.833sec(infer)
# Epoch 294 tst: l 0.207 a 0.942 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.918sec
# Epoch 295 tr: l 0.153 a 0.954 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.403sec(train) 2.796sec(infer)
# Epoch 295 tst: l 0.206 a 0.942 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.893sec
# Epoch 296 tr: l 0.152 a 0.953 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 22.078sec(train) 2.805sec(infer)
# Epoch 296 tst: l 0.205 a 0.942 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.889sec
# Epoch 297 tr: l 0.151 a 0.954 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 23.624sec(train) 2.834sec(infer)
# Epoch 297 tst: l 0.205 a 0.942 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.892sec
# Epoch 298 tr: l 0.153 a 0.953 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 21.696sec(train) 2.837sec(infer)
# Epoch 298 tst: l 0.204 a 0.942 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.896sec
# Epoch 299 tr: l 0.154 a 0.954 clct[np.int64(299), np.int64(300), np.int64(301), np.int64(300)] cl_acc 0.999  lr 0.100000 21.901sec(train) 2.963sec(infer)
# Epoch 299 tst: l 0.204 a 0.942 clct[np.int64(49), np.int64(50), np.int64(51), np.int64(50)] cl_acc 0.995  1.895sec
# result written at output_dfca_li/results.pickle
# checkpoint written at output_dfca_li/checkpoint.pt
# ---train cluster Ended in 2.40 hour (8630.560 sec)

# %% [markdown]
# IFCA Experiment Outputs

# %%
___.display_outputs()
# Out:
# ---------------------------------DFCA-GI, lr: 0.1, seed: 1824---------------------------------
# config: {'m': 1200, 'm_test': 200, 'p': 4, 'n': 200, 'uneven': True, 'local_model_init': False, 'h1': 200, 'num_epochs': 300, 'batch_size': 100, 'tau': 10, 'lr': 0.1, 'data_seed': 1824, 'train_seed': 1824, 'config_override': '', 'project_dir': 'output_dfca_gi'}
# Using device: cuda:0
# Epoch -1 tr: l 2.292 a 0.116 clct[np.int64(892), np.int64(109), np.int64(140), np.int64(59)] cl_acc 0.321  24.447sec
# Epoch -1 tst: l 2.292 a 0.127 clct[np.int64(151), np.int64(13), np.int64(22), np.int64(14)] cl_acc 0.305  15.610sec
# Epoch 0 tr: l 2.132 a 0.326 clct[np.int64(627), np.int64(234), np.int64(215), np.int64(124)] cl_acc 0.423  lr 0.100000 27.158sec(train) 24.218sec(infer)
# Epoch 0 tst: l 2.188 a 0.291 clct[np.int64(102), np.int64(44), np.int64(36), np.int64(18)] cl_acc 0.460  15.721sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 1 tr: l 1.949 a 0.501 clct[np.int64(323), np.int64(376), np.int64(269), np.int64(232)] cl_acc 0.665  lr 0.100000 26.888sec(train) 26.007sec(infer)
# Epoch 1 tst: l 2.025 a 0.451 clct[np.int64(60), np.int64(59), np.int64(48), np.int64(33)] cl_acc 0.655  15.929sec
# Epoch 2 tr: l 1.688 a 0.644 clct[np.int64(254), np.int64(375), np.int64(279), np.int64(292)] cl_acc 0.862  lr 0.100000 27.383sec(train) 25.589sec(infer)
# Epoch 2 tst: l 1.770 a 0.603 clct[np.int64(36), np.int64(70), np.int64(47), np.int64(47)] cl_acc 0.860  16.717sec
# Epoch 3 tr: l 1.394 a 0.738 clct[np.int64(301), np.int64(308), np.int64(292), np.int64(299)] cl_acc 0.968  lr 0.100000 28.320sec(train) 26.941sec(infer)
# Epoch 3 tst: l 1.453 a 0.712 clct[np.int64(52), np.int64(51), np.int64(47), np.int64(50)] cl_acc 0.980  15.383sec
# Epoch 4 tr: l 1.114 a 0.788 clct[np.int64(301), np.int64(301), np.int64(296), np.int64(302)] cl_acc 0.994  lr 0.100000 27.778sec(train) 25.760sec(infer)
# Epoch 4 tst: l 1.170 a 0.772 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.053sec
# Epoch 5 tr: l 0.920 a 0.816 clct[np.int64(300), np.int64(301), np.int64(299), np.int64(300)] cl_acc 0.998  lr 0.100000 28.526sec(train) 25.265sec(infer)
# Epoch 5 tst: l 0.964 a 0.803 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.289sec
# Epoch 6 tr: l 0.787 a 0.835 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 28.712sec(train) 26.662sec(infer)
# Epoch 6 tst: l 0.825 a 0.822 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.669sec
# Epoch 7 tr: l 0.699 a 0.847 clct[np.int64(301), np.int64(300), np.int64(299), np.int64(300)] cl_acc 0.999  lr 0.100000 28.444sec(train) 25.418sec(infer)
# Epoch 7 tst: l 0.726 a 0.836 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.885sec
# Epoch 8 tr: l 0.630 a 0.857 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.496sec(train) 26.188sec(infer)
# Epoch 8 tst: l 0.655 a 0.846 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.722sec
# Epoch 9 tr: l 0.576 a 0.865 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.276sec(train) 27.877sec(infer)
# Epoch 9 tst: l 0.603 a 0.854 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.165sec
# Epoch 10 tr: l 0.535 a 0.870 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.525sec(train) 26.399sec(infer)
# Epoch 10 tst: l 0.560 a 0.862 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  19.002sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 11 tr: l 0.504 a 0.874 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 25.372sec(train) 6.672sec(infer)
# Epoch 11 tst: l 0.528 a 0.867 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  4.154sec
# Epoch 12 tr: l 0.478 a 0.879 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 24.582sec(train) 6.622sec(infer)
# Epoch 12 tst: l 0.500 a 0.872 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  3.980sec
# Epoch 13 tr: l 0.458 a 0.882 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 19.849sec(train) 6.970sec(infer)
# Epoch 13 tst: l 0.479 a 0.876 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  7.162sec
# Epoch 14 tr: l 0.439 a 0.886 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.615sec(train) 26.277sec(infer)
# Epoch 14 tst: l 0.460 a 0.879 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.257sec
# Epoch 15 tr: l 0.428 a 0.887 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.020sec(train) 27.650sec(infer)
# Epoch 15 tst: l 0.446 a 0.881 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.605sec
# Epoch 16 tr: l 0.411 a 0.890 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.529sec(train) 26.268sec(infer)
# Epoch 16 tst: l 0.431 a 0.885 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.650sec
# Epoch 17 tr: l 0.402 a 0.892 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.863sec(train) 27.209sec(infer)
# Epoch 17 tst: l 0.419 a 0.887 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.714sec
# Epoch 18 tr: l 0.389 a 0.894 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.328sec(train) 27.604sec(infer)
# Epoch 18 tst: l 0.408 a 0.889 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.421sec
# Epoch 19 tr: l 0.378 a 0.896 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.564sec(train) 26.770sec(infer)
# Epoch 19 tst: l 0.400 a 0.890 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.614sec
# Epoch 20 tr: l 0.369 a 0.897 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.108sec(train) 28.382sec(infer)
# Epoch 20 tst: l 0.392 a 0.891 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.070sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 21 tr: l 0.365 a 0.898 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.639sec(train) 27.940sec(infer)
# Epoch 21 tst: l 0.386 a 0.892 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.912sec
# Epoch 22 tr: l 0.355 a 0.900 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.974sec(train) 28.252sec(infer)
# Epoch 22 tst: l 0.378 a 0.893 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.085sec
# Epoch 23 tr: l 0.352 a 0.901 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.503sec(train) 28.941sec(infer)
# Epoch 23 tst: l 0.372 a 0.895 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.028sec
# Epoch 24 tr: l 0.348 a 0.901 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.914sec(train) 26.899sec(infer)
# Epoch 24 tst: l 0.366 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.891sec
# Epoch 25 tr: l 0.340 a 0.903 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.130sec(train) 27.144sec(infer)
# Epoch 25 tst: l 0.361 a 0.896 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.607sec
# Epoch 26 tr: l 0.339 a 0.904 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.037sec(train) 27.258sec(infer)
# Epoch 26 tst: l 0.356 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.127sec
# Epoch 27 tr: l 0.331 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.179sec(train) 25.465sec(infer)
# Epoch 27 tst: l 0.352 a 0.898 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.301sec
# Epoch 28 tr: l 0.327 a 0.905 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.330sec(train) 26.427sec(infer)
# Epoch 28 tst: l 0.349 a 0.899 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.223sec
# Epoch 29 tr: l 0.322 a 0.907 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.900sec(train) 27.002sec(infer)
# Epoch 29 tst: l 0.345 a 0.900 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.791sec
# Epoch 30 tr: l 0.320 a 0.907 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.330sec(train) 25.751sec(infer)
# Epoch 30 tst: l 0.340 a 0.901 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.303sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 31 tr: l 0.314 a 0.909 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.520sec(train) 27.028sec(infer)
# Epoch 31 tst: l 0.339 a 0.901 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.613sec
# Epoch 32 tr: l 0.315 a 0.908 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.643sec(train) 27.298sec(infer)
# Epoch 32 tst: l 0.335 a 0.902 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.421sec
# Epoch 33 tr: l 0.311 a 0.909 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.220sec(train) 26.611sec(infer)
# Epoch 33 tst: l 0.333 a 0.903 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.387sec
# Epoch 34 tr: l 0.307 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.175sec(train) 28.238sec(infer)
# Epoch 34 tst: l 0.329 a 0.903 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.543sec
# Epoch 35 tr: l 0.306 a 0.910 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.035sec(train) 27.194sec(infer)
# Epoch 35 tst: l 0.327 a 0.903 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.835sec
# Epoch 36 tr: l 0.304 a 0.911 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.670sec(train) 24.866sec(infer)
# Epoch 36 tst: l 0.324 a 0.904 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.126sec
# Epoch 37 tr: l 0.299 a 0.912 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.051sec(train) 25.900sec(infer)
# Epoch 37 tst: l 0.323 a 0.905 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.173sec
# Epoch 38 tr: l 0.296 a 0.912 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.124sec(train) 25.160sec(infer)
# Epoch 38 tst: l 0.320 a 0.906 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.293sec
# Epoch 39 tr: l 0.295 a 0.913 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.249sec(train) 24.625sec(infer)
# Epoch 39 tst: l 0.317 a 0.907 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.715sec
# Epoch 40 tr: l 0.290 a 0.914 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.901sec(train) 25.893sec(infer)
# Epoch 40 tst: l 0.315 a 0.907 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.065sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 41 tr: l 0.290 a 0.913 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.286sec(train) 25.666sec(infer)
# Epoch 41 tst: l 0.315 a 0.907 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.843sec
# Epoch 42 tr: l 0.286 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.052sec(train) 24.576sec(infer)
# Epoch 42 tst: l 0.313 a 0.907 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.602sec
# Epoch 43 tr: l 0.285 a 0.916 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.050sec(train) 25.677sec(infer)
# Epoch 43 tst: l 0.309 a 0.908 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.497sec
# Epoch 44 tr: l 0.286 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.093sec(train) 25.749sec(infer)
# Epoch 44 tst: l 0.308 a 0.909 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.474sec
# Epoch 45 tr: l 0.283 a 0.915 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.407sec(train) 25.155sec(infer)
# Epoch 45 tst: l 0.306 a 0.909 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.527sec
# Epoch 46 tr: l 0.279 a 0.917 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.630sec(train) 26.230sec(infer)
# Epoch 46 tst: l 0.306 a 0.909 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.539sec
# Epoch 47 tr: l 0.275 a 0.917 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.882sec(train) 26.249sec(infer)
# Epoch 47 tst: l 0.303 a 0.910 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.880sec
# Epoch 48 tr: l 0.274 a 0.918 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.065sec(train) 25.568sec(infer)
# Epoch 48 tst: l 0.302 a 0.911 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.949sec
# Epoch 49 tr: l 0.271 a 0.919 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.869sec(train) 26.878sec(infer)
# Epoch 49 tst: l 0.301 a 0.911 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.506sec
# Epoch 50 tr: l 0.272 a 0.918 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.017sec(train) 26.906sec(infer)
# Epoch 50 tst: l 0.299 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.168sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 51 tr: l 0.270 a 0.919 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.112sec(train) 26.299sec(infer)
# Epoch 51 tst: l 0.297 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.199sec
# Epoch 52 tr: l 0.268 a 0.920 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.717sec(train) 26.943sec(infer)
# Epoch 52 tst: l 0.297 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.279sec
# Epoch 53 tr: l 0.267 a 0.920 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.649sec(train) 26.649sec(infer)
# Epoch 53 tst: l 0.296 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.002sec
# Epoch 54 tr: l 0.267 a 0.921 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.069sec(train) 25.524sec(infer)
# Epoch 54 tst: l 0.294 a 0.912 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.250sec
# Epoch 55 tr: l 0.263 a 0.921 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.776sec(train) 25.834sec(infer)
# Epoch 55 tst: l 0.292 a 0.914 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.459sec
# Epoch 56 tr: l 0.265 a 0.920 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.078sec(train) 25.844sec(infer)
# Epoch 56 tst: l 0.290 a 0.914 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.897sec
# Epoch 57 tr: l 0.260 a 0.922 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 30.380sec(train) 23.978sec(infer)
# Epoch 57 tst: l 0.290 a 0.914 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.633sec
# Epoch 58 tr: l 0.256 a 0.923 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.254sec(train) 19.960sec(infer)
# Epoch 58 tst: l 0.290 a 0.914 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.516sec
# Epoch 59 tr: l 0.262 a 0.921 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.557sec(train) 25.526sec(infer)
# Epoch 59 tst: l 0.287 a 0.915 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.048sec
# Epoch 60 tr: l 0.262 a 0.921 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.719sec(train) 24.325sec(infer)
# Epoch 60 tst: l 0.285 a 0.915 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.970sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 61 tr: l 0.256 a 0.922 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.449sec(train) 24.841sec(infer)
# Epoch 61 tst: l 0.285 a 0.916 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.041sec
# Epoch 62 tr: l 0.255 a 0.922 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.688sec(train) 25.841sec(infer)
# Epoch 62 tst: l 0.284 a 0.916 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.582sec
# Epoch 63 tr: l 0.256 a 0.923 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.203sec(train) 24.694sec(infer)
# Epoch 63 tst: l 0.283 a 0.916 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.091sec
# Epoch 64 tr: l 0.255 a 0.924 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.524sec(train) 25.467sec(infer)
# Epoch 64 tst: l 0.282 a 0.917 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.191sec
# Epoch 65 tr: l 0.247 a 0.925 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.487sec(train) 25.186sec(infer)
# Epoch 65 tst: l 0.281 a 0.917 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.457sec
# Epoch 66 tr: l 0.251 a 0.925 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.733sec(train) 24.934sec(infer)
# Epoch 66 tst: l 0.280 a 0.917 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.510sec
# Epoch 67 tr: l 0.250 a 0.925 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.595sec(train) 25.652sec(infer)
# Epoch 67 tst: l 0.279 a 0.917 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.763sec
# Epoch 68 tr: l 0.250 a 0.925 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.603sec(train) 25.244sec(infer)
# Epoch 68 tst: l 0.278 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.365sec
# Epoch 69 tr: l 0.248 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.747sec(train) 23.994sec(infer)
# Epoch 69 tst: l 0.277 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.613sec
# Epoch 70 tr: l 0.244 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.177sec(train) 24.974sec(infer)
# Epoch 70 tst: l 0.277 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.572sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 71 tr: l 0.246 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.518sec(train) 25.250sec(infer)
# Epoch 71 tst: l 0.276 a 0.918 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.249sec
# Epoch 72 tr: l 0.248 a 0.926 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.463sec(train) 23.979sec(infer)
# Epoch 72 tst: l 0.275 a 0.919 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.622sec
# Epoch 73 tr: l 0.242 a 0.927 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.143sec(train) 25.094sec(infer)
# Epoch 73 tst: l 0.273 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.227sec
# Epoch 74 tr: l 0.241 a 0.928 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.332sec(train) 25.810sec(infer)
# Epoch 74 tst: l 0.273 a 0.919 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.577sec
# Epoch 75 tr: l 0.240 a 0.928 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.200sec(train) 24.569sec(infer)
# Epoch 75 tst: l 0.271 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.492sec
# Epoch 76 tr: l 0.238 a 0.928 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.750sec(train) 25.690sec(infer)
# Epoch 76 tst: l 0.272 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.750sec
# Epoch 77 tr: l 0.237 a 0.928 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.825sec(train) 26.281sec(infer)
# Epoch 77 tst: l 0.270 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.940sec
# Epoch 78 tr: l 0.237 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.220sec(train) 25.354sec(infer)
# Epoch 78 tst: l 0.268 a 0.920 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.788sec
# Epoch 79 tr: l 0.238 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.212sec(train) 26.356sec(infer)
# Epoch 79 tst: l 0.267 a 0.921 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.178sec
# Epoch 80 tr: l 0.235 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.878sec(train) 26.706sec(infer)
# Epoch 80 tst: l 0.268 a 0.921 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.209sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 81 tr: l 0.235 a 0.929 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.514sec(train) 25.783sec(infer)
# Epoch 81 tst: l 0.266 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.671sec
# Epoch 82 tr: l 0.235 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.034sec(train) 27.162sec(infer)
# Epoch 82 tst: l 0.265 a 0.921 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.998sec
# Epoch 83 tr: l 0.233 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.159sec(train) 25.720sec(infer)
# Epoch 83 tst: l 0.265 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.705sec
# Epoch 84 tr: l 0.230 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.202sec(train) 25.653sec(infer)
# Epoch 84 tst: l 0.264 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.174sec
# Epoch 85 tr: l 0.232 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.023sec(train) 26.163sec(infer)
# Epoch 85 tst: l 0.263 a 0.922 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.923sec
# Epoch 86 tr: l 0.233 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.838sec(train) 25.247sec(infer)
# Epoch 86 tst: l 0.262 a 0.923 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.295sec
# Epoch 87 tr: l 0.232 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.521sec(train) 24.420sec(infer)
# Epoch 87 tst: l 0.262 a 0.923 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.170sec
# Epoch 88 tr: l 0.232 a 0.930 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.574sec(train) 24.966sec(infer)
# Epoch 88 tst: l 0.260 a 0.923 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.842sec
# Epoch 89 tr: l 0.228 a 0.931 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.639sec(train) 25.050sec(infer)
# Epoch 89 tst: l 0.260 a 0.923 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.116sec
# Epoch 90 tr: l 0.226 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.612sec(train) 24.019sec(infer)
# Epoch 90 tst: l 0.258 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.812sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 91 tr: l 0.230 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.979sec(train) 25.120sec(infer)
# Epoch 91 tst: l 0.258 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.260sec
# Epoch 92 tr: l 0.225 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 25.761sec(train) 25.286sec(infer)
# Epoch 92 tst: l 0.258 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.617sec
# Epoch 93 tr: l 0.225 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.406sec(train) 24.411sec(infer)
# Epoch 93 tst: l 0.257 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.962sec
# Epoch 94 tr: l 0.221 a 0.933 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.998sec(train) 25.043sec(infer)
# Epoch 94 tst: l 0.256 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.477sec
# Epoch 95 tr: l 0.223 a 0.933 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.178sec(train) 26.030sec(infer)
# Epoch 95 tst: l 0.255 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.989sec
# Epoch 96 tr: l 0.222 a 0.933 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.214sec(train) 26.027sec(infer)
# Epoch 96 tst: l 0.254 a 0.925 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.727sec
# Epoch 97 tr: l 0.225 a 0.932 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.324sec(train) 26.028sec(infer)
# Epoch 97 tst: l 0.256 a 0.924 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.176sec
# Epoch 98 tr: l 0.220 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.434sec(train) 24.540sec(infer)
# Epoch 98 tst: l 0.252 a 0.925 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.995sec
# Epoch 99 tr: l 0.220 a 0.933 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.551sec(train) 24.776sec(infer)
# Epoch 99 tst: l 0.252 a 0.925 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.922sec
# Epoch 100 tr: l 0.220 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.577sec(train) 25.249sec(infer)
# Epoch 100 tst: l 0.252 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.437sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 101 tr: l 0.218 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.490sec(train) 24.258sec(infer)
# Epoch 101 tst: l 0.252 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.137sec
# Epoch 102 tr: l 0.217 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.509sec(train) 24.703sec(infer)
# Epoch 102 tst: l 0.250 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.819sec
# Epoch 103 tr: l 0.217 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.163sec(train) 19.976sec(infer)
# Epoch 103 tst: l 0.249 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.390sec
# Epoch 104 tr: l 0.217 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.418sec(train) 24.397sec(infer)
# Epoch 104 tst: l 0.249 a 0.926 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.989sec
# Epoch 105 tr: l 0.215 a 0.934 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.227sec(train) 24.884sec(infer)
# Epoch 105 tst: l 0.247 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.327sec
# Epoch 106 tr: l 0.213 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.926sec(train) 26.225sec(infer)
# Epoch 106 tst: l 0.246 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.125sec
# Epoch 107 tr: l 0.212 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.725sec(train) 25.169sec(infer)
# Epoch 107 tst: l 0.247 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.916sec
# Epoch 108 tr: l 0.216 a 0.935 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.655sec(train) 25.716sec(infer)
# Epoch 108 tst: l 0.246 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.510sec
# Epoch 109 tr: l 0.212 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.405sec(train) 26.721sec(infer)
# Epoch 109 tst: l 0.246 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.474sec
# Epoch 110 tr: l 0.211 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.038sec(train) 25.561sec(infer)
# Epoch 110 tst: l 0.245 a 0.928 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.093sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 111 tr: l 0.212 a 0.936 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.285sec(train) 26.743sec(infer)
# Epoch 111 tst: l 0.243 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.661sec
# Epoch 112 tr: l 0.208 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.180sec(train) 26.894sec(infer)
# Epoch 112 tst: l 0.243 a 0.927 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.196sec
# Epoch 113 tr: l 0.207 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.469sec(train) 24.929sec(infer)
# Epoch 113 tst: l 0.243 a 0.928 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.252sec
# Epoch 114 tr: l 0.204 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.850sec(train) 25.598sec(infer)
# Epoch 114 tst: l 0.242 a 0.928 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.905sec
# Epoch 115 tr: l 0.206 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.245sec(train) 25.548sec(infer)
# Epoch 115 tst: l 0.240 a 0.928 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.108sec
# Epoch 116 tr: l 0.204 a 0.939 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.405sec(train) 24.136sec(infer)
# Epoch 116 tst: l 0.240 a 0.928 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.096sec
# Epoch 117 tr: l 0.204 a 0.939 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.572sec(train) 24.461sec(infer)
# Epoch 117 tst: l 0.239 a 0.929 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.613sec
# Epoch 118 tr: l 0.203 a 0.939 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.298sec(train) 25.441sec(infer)
# Epoch 118 tst: l 0.239 a 0.929 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.495sec
# Epoch 119 tr: l 0.203 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.509sec(train) 24.534sec(infer)
# Epoch 119 tst: l 0.239 a 0.929 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.055sec
# Epoch 120 tr: l 0.203 a 0.939 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.524sec(train) 24.531sec(infer)
# Epoch 120 tst: l 0.238 a 0.929 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  19.069sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 121 tr: l 0.204 a 0.939 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.330sec(train) 26.075sec(infer)
# Epoch 121 tst: l 0.239 a 0.929 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.549sec
# Epoch 122 tr: l 0.205 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.265sec(train) 25.028sec(infer)
# Epoch 122 tst: l 0.236 a 0.930 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.372sec
# Epoch 123 tr: l 0.203 a 0.938 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.562sec(train) 24.716sec(infer)
# Epoch 123 tst: l 0.236 a 0.930 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.359sec
# Epoch 124 tr: l 0.200 a 0.939 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.428sec(train) 26.229sec(infer)
# Epoch 124 tst: l 0.235 a 0.930 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.254sec
# Epoch 125 tr: l 0.202 a 0.940 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.687sec(train) 24.468sec(infer)
# Epoch 125 tst: l 0.234 a 0.930 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.234sec
# Epoch 126 tr: l 0.199 a 0.940 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.281sec(train) 24.643sec(infer)
# Epoch 126 tst: l 0.236 a 0.929 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.481sec
# Epoch 127 tr: l 0.199 a 0.940 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.518sec(train) 25.548sec(infer)
# Epoch 127 tst: l 0.234 a 0.930 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.666sec
# Epoch 128 tr: l 0.197 a 0.941 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.985sec(train) 24.337sec(infer)
# Epoch 128 tst: l 0.234 a 0.931 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.356sec
# Epoch 129 tr: l 0.198 a 0.940 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.586sec(train) 24.399sec(infer)
# Epoch 129 tst: l 0.232 a 0.931 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.599sec
# Epoch 130 tr: l 0.193 a 0.942 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.927sec(train) 25.603sec(infer)
# Epoch 130 tst: l 0.232 a 0.931 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.273sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 131 tr: l 0.197 a 0.941 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.632sec(train) 24.632sec(infer)
# Epoch 131 tst: l 0.231 a 0.931 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.236sec
# Epoch 132 tr: l 0.195 a 0.941 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.799sec(train) 25.127sec(infer)
# Epoch 132 tst: l 0.231 a 0.931 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.475sec
# Epoch 133 tr: l 0.196 a 0.942 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.201sec(train) 26.106sec(infer)
# Epoch 133 tst: l 0.231 a 0.931 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.268sec
# Epoch 134 tr: l 0.194 a 0.942 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.198sec(train) 25.004sec(infer)
# Epoch 134 tst: l 0.229 a 0.932 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.981sec
# Epoch 135 tr: l 0.194 a 0.942 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.480sec(train) 26.025sec(infer)
# Epoch 135 tst: l 0.230 a 0.932 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.568sec
# Epoch 136 tr: l 0.195 a 0.942 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.362sec(train) 26.196sec(infer)
# Epoch 136 tst: l 0.228 a 0.932 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.612sec
# Epoch 137 tr: l 0.192 a 0.942 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.511sec(train) 25.262sec(infer)
# Epoch 137 tst: l 0.228 a 0.932 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.274sec
# Epoch 138 tr: l 0.193 a 0.942 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.171sec(train) 26.921sec(infer)
# Epoch 138 tst: l 0.228 a 0.932 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.487sec
# Epoch 139 tr: l 0.194 a 0.942 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.036sec(train) 26.694sec(infer)
# Epoch 139 tst: l 0.226 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.163sec
# Epoch 140 tr: l 0.191 a 0.943 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.240sec(train) 26.112sec(infer)
# Epoch 140 tst: l 0.226 a 0.932 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.102sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 141 tr: l 0.188 a 0.943 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.893sec(train) 26.359sec(infer)
# Epoch 141 tst: l 0.226 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.946sec
# Epoch 142 tr: l 0.189 a 0.943 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.432sec(train) 24.688sec(infer)
# Epoch 142 tst: l 0.225 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.128sec
# Epoch 143 tr: l 0.189 a 0.944 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.489sec(train) 25.308sec(infer)
# Epoch 143 tst: l 0.225 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.881sec
# Epoch 144 tr: l 0.189 a 0.943 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.201sec(train) 25.418sec(infer)
# Epoch 144 tst: l 0.224 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.071sec
# Epoch 145 tr: l 0.187 a 0.943 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.703sec(train) 23.838sec(infer)
# Epoch 145 tst: l 0.223 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.273sec
# Epoch 146 tr: l 0.187 a 0.944 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.278sec(train) 24.588sec(infer)
# Epoch 146 tst: l 0.223 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.387sec
# Epoch 147 tr: l 0.185 a 0.944 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.103sec(train) 25.455sec(infer)
# Epoch 147 tst: l 0.222 a 0.933 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.866sec
# Epoch 148 tr: l 0.185 a 0.944 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.779sec(train) 20.323sec(infer)
# Epoch 148 tst: l 0.221 a 0.934 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.967sec
# Epoch 149 tr: l 0.185 a 0.945 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.063sec(train) 24.875sec(infer)
# Epoch 149 tst: l 0.221 a 0.934 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.190sec
# Epoch 150 tr: l 0.184 a 0.944 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.663sec(train) 25.760sec(infer)
# Epoch 150 tst: l 0.221 a 0.934 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  17.345sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 151 tr: l 0.184 a 0.945 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.660sec(train) 24.762sec(infer)
# Epoch 151 tst: l 0.220 a 0.934 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  18.094sec
# Epoch 152 tr: l 0.183 a 0.945 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.239sec(train) 24.013sec(infer)
# Epoch 152 tst: l 0.220 a 0.934 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.841sec
# Epoch 153 tr: l 0.183 a 0.945 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.998sec(train) 23.784sec(infer)
# Epoch 153 tst: l 0.219 a 0.934 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.100sec
# Epoch 154 tr: l 0.185 a 0.945 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.702sec(train) 22.896sec(infer)
# Epoch 154 tst: l 0.218 a 0.934 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.393sec
# Epoch 155 tr: l 0.180 a 0.946 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.031sec(train) 22.903sec(infer)
# Epoch 155 tst: l 0.217 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.156sec
# Epoch 156 tr: l 0.180 a 0.946 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 26.996sec(train) 23.744sec(infer)
# Epoch 156 tst: l 0.217 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.277sec
# Epoch 157 tr: l 0.181 a 0.945 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.725sec(train) 23.199sec(infer)
# Epoch 157 tst: l 0.217 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.087sec
# Epoch 158 tr: l 0.180 a 0.946 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.159sec(train) 22.411sec(infer)
# Epoch 158 tst: l 0.217 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.385sec
# Epoch 159 tr: l 0.179 a 0.947 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.338sec(train) 23.566sec(infer)
# Epoch 159 tst: l 0.215 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.436sec
# Epoch 160 tr: l 0.181 a 0.946 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.631sec(train) 23.303sec(infer)
# Epoch 160 tst: l 0.215 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.031sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 161 tr: l 0.180 a 0.946 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.843sec(train) 22.512sec(infer)
# Epoch 161 tst: l 0.216 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.445sec
# Epoch 162 tr: l 0.179 a 0.946 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.058sec(train) 23.666sec(infer)
# Epoch 162 tst: l 0.214 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.889sec
# Epoch 163 tr: l 0.180 a 0.946 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.410sec(train) 23.339sec(infer)
# Epoch 163 tst: l 0.213 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.607sec
# Epoch 164 tr: l 0.177 a 0.947 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.792sec(train) 22.467sec(infer)
# Epoch 164 tst: l 0.214 a 0.935 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.622sec
# Epoch 165 tr: l 0.177 a 0.947 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 28.559sec(train) 23.371sec(infer)
# Epoch 165 tst: l 0.213 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.450sec
# Epoch 166 tr: l 0.176 a 0.947 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.934sec(train) 22.961sec(infer)
# Epoch 166 tst: l 0.212 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.566sec
# Epoch 167 tr: l 0.176 a 0.947 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 29.167sec(train) 22.607sec(infer)
# Epoch 167 tst: l 0.212 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  16.560sec
# Epoch 168 tr: l 0.174 a 0.947 clct[np.int64(300), np.int64(300), np.int64(300), np.int64(300)] cl_acc 1.000  lr 0.100000 27.397sec(train) 23.704sec(infer)
# Epoch 168 tst: l 0.213 a 0.936 clct[np.int64(50), np.int64(50), np.int64(50), np.int64(50)] cl_acc 1.000  15.136sec
# ...
# Epoch 243 tr: l 0.145 a 0.956 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.556sec(train) 3.158sec(infer)
# Epoch 243 tst: l 0.193 a 0.945 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.967sec
# Epoch 244 tr: l 0.141 a 0.957 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.870sec(train) 3.165sec(infer)
# Epoch 244 tst: l 0.192 a 0.945 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.994sec
# Epoch 245 tr: l 0.141 a 0.957 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.828sec(train) 3.137sec(infer)
# Epoch 245 tst: l 0.192 a 0.945 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.964sec
# Epoch 246 tr: l 0.141 a 0.957 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.400sec(train) 3.162sec(infer)
# Epoch 246 tst: l 0.191 a 0.945 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.046sec
# Epoch 247 tr: l 0.141 a 0.957 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.940sec(train) 3.155sec(infer)
# Epoch 247 tst: l 0.191 a 0.945 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.058sec
# Epoch 248 tr: l 0.142 a 0.957 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.930sec(train) 3.170sec(infer)
# Epoch 248 tst: l 0.190 a 0.945 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.061sec
# Epoch 249 tr: l 0.141 a 0.957 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.399sec(train) 3.160sec(infer)
# Epoch 249 tst: l 0.190 a 0.945 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.136sec
# Epoch 250 tr: l 0.141 a 0.957 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.101sec(train) 3.159sec(infer)
# Epoch 250 tst: l 0.191 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.137sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 251 tr: l 0.139 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.287sec(train) 3.160sec(infer)
# Epoch 251 tst: l 0.190 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.139sec
# Epoch 252 tr: l 0.138 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.061sec(train) 3.163sec(infer)
# Epoch 252 tst: l 0.189 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.139sec
# Epoch 253 tr: l 0.139 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.988sec(train) 2.946sec(infer)
# Epoch 253 tst: l 0.188 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.142sec
# Epoch 254 tr: l 0.140 a 0.957 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.606sec(train) 3.015sec(infer)
# Epoch 254 tst: l 0.189 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.139sec
# Epoch 255 tr: l 0.138 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.688sec(train) 3.152sec(infer)
# Epoch 255 tst: l 0.189 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.126sec
# Epoch 256 tr: l 0.141 a 0.957 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.119sec(train) 2.752sec(infer)
# Epoch 256 tst: l 0.188 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.145sec
# Epoch 257 tr: l 0.138 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.915sec(train) 3.021sec(infer)
# Epoch 257 tst: l 0.188 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.145sec
# Epoch 258 tr: l 0.136 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.372sec(train) 2.831sec(infer)
# Epoch 258 tst: l 0.188 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.142sec
# Epoch 259 tr: l 0.138 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.480sec(train) 2.773sec(infer)
# Epoch 259 tst: l 0.187 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.939sec
# Epoch 260 tr: l 0.137 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.714sec(train) 2.777sec(infer)
# Epoch 260 tst: l 0.187 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.878sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 261 tr: l 0.136 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.319sec(train) 2.788sec(infer)
# Epoch 261 tst: l 0.187 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.879sec
# Epoch 262 tr: l 0.137 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.128sec(train) 2.787sec(infer)
# Epoch 262 tst: l 0.186 a 0.946 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.880sec
# Epoch 263 tr: l 0.134 a 0.959 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.073sec(train) 2.793sec(infer)
# Epoch 263 tst: l 0.186 a 0.947 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.883sec
# Epoch 264 tr: l 0.138 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.662sec(train) 2.797sec(infer)
# Epoch 264 tst: l 0.185 a 0.947 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.883sec
# Epoch 265 tr: l 0.134 a 0.959 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.348sec(train) 2.794sec(infer)
# Epoch 265 tst: l 0.185 a 0.947 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.881sec
# Epoch 266 tr: l 0.135 a 0.959 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.371sec(train) 2.830sec(infer)
# Epoch 266 tst: l 0.185 a 0.947 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.922sec
# Epoch 267 tr: l 0.137 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.525sec(train) 2.781sec(infer)
# Epoch 267 tst: l 0.184 a 0.947 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.878sec
# Epoch 268 tr: l 0.135 a 0.958 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 24.200sec(train) 2.824sec(infer)
# Epoch 268 tst: l 0.184 a 0.947 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.912sec
# Epoch 269 tr: l 0.134 a 0.959 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.526sec(train) 2.779sec(infer)
# Epoch 269 tst: l 0.185 a 0.947 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.883sec
# Epoch 270 tr: l 0.134 a 0.959 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.667sec(train) 2.840sec(infer)
# Epoch 270 tst: l 0.184 a 0.948 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.909sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 271 tr: l 0.133 a 0.959 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.087sec(train) 2.786sec(infer)
# Epoch 271 tst: l 0.184 a 0.947 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.881sec
# Epoch 272 tr: l 0.134 a 0.959 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 24.087sec(train) 2.845sec(infer)
# Epoch 272 tst: l 0.183 a 0.947 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.900sec
# Epoch 273 tr: l 0.133 a 0.959 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.293sec(train) 2.923sec(infer)
# Epoch 273 tst: l 0.182 a 0.948 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.918sec
# Epoch 274 tr: l 0.134 a 0.959 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.707sec(train) 2.894sec(infer)
# Epoch 274 tst: l 0.181 a 0.948 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.918sec
# Epoch 275 tr: l 0.134 a 0.959 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.063sec(train) 2.791sec(infer)
# Epoch 275 tst: l 0.181 a 0.948 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.879sec
# Epoch 276 tr: l 0.132 a 0.960 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.213sec(train) 2.799sec(infer)
# Epoch 276 tst: l 0.182 a 0.948 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.201sec
# Epoch 277 tr: l 0.133 a 0.959 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.566sec(train) 3.079sec(infer)
# Epoch 277 tst: l 0.181 a 0.948 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.952sec
# Epoch 278 tr: l 0.131 a 0.960 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.469sec(train) 3.166sec(infer)
# Epoch 278 tst: l 0.181 a 0.948 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.990sec
# Epoch 279 tr: l 0.129 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.398sec(train) 3.164sec(infer)
# Epoch 279 tst: l 0.181 a 0.948 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.082sec
# Epoch 280 tr: l 0.132 a 0.960 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.332sec(train) 3.174sec(infer)
# Epoch 280 tst: l 0.181 a 0.948 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.043sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 281 tr: l 0.131 a 0.960 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.689sec(train) 3.171sec(infer)
# Epoch 281 tst: l 0.180 a 0.948 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.987sec
# Epoch 282 tr: l 0.132 a 0.960 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.651sec(train) 3.165sec(infer)
# Epoch 282 tst: l 0.179 a 0.949 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.138sec
# Epoch 283 tr: l 0.129 a 0.960 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.324sec(train) 3.165sec(infer)
# Epoch 283 tst: l 0.179 a 0.948 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.144sec
# Epoch 284 tr: l 0.129 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.508sec(train) 3.160sec(infer)
# Epoch 284 tst: l 0.179 a 0.949 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.985sec
# Epoch 285 tr: l 0.129 a 0.960 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.377sec(train) 3.174sec(infer)
# Epoch 285 tst: l 0.178 a 0.949 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.089sec
# Epoch 286 tr: l 0.129 a 0.960 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.643sec(train) 3.166sec(infer)
# Epoch 286 tst: l 0.178 a 0.949 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.143sec
# Epoch 287 tr: l 0.129 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.281sec(train) 3.015sec(infer)
# Epoch 287 tst: l 0.178 a 0.949 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.140sec
# Epoch 288 tr: l 0.128 a 0.960 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.431sec(train) 2.996sec(infer)
# Epoch 288 tst: l 0.178 a 0.949 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.147sec
# Epoch 289 tr: l 0.129 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.124sec(train) 2.777sec(infer)
# Epoch 289 tst: l 0.178 a 0.949 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.150sec
# Epoch 290 tr: l 0.129 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.522sec(train) 2.756sec(infer)
# Epoch 290 tst: l 0.177 a 0.949 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.148sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# Epoch 291 tr: l 0.128 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 21.786sec(train) 2.745sec(infer)
# Epoch 291 tst: l 0.177 a 0.949 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.145sec
# Epoch 292 tr: l 0.127 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.657sec(train) 3.013sec(infer)
# Epoch 292 tst: l 0.176 a 0.949 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.127sec
# Epoch 293 tr: l 0.128 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.473sec(train) 3.007sec(infer)
# Epoch 293 tst: l 0.176 a 0.949 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.135sec
# Epoch 294 tr: l 0.127 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.515sec(train) 3.170sec(infer)
# Epoch 294 tst: l 0.176 a 0.949 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  2.069sec
# Epoch 295 tr: l 0.129 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.728sec(train) 3.044sec(infer)
# Epoch 295 tst: l 0.176 a 0.950 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.956sec
# Epoch 296 tr: l 0.127 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.272sec(train) 1.599sec(infer)
# Epoch 296 tst: l 0.175 a 0.950 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.117sec
# Epoch 297 tr: l 0.127 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.210sec(train) 1.591sec(infer)
# Epoch 297 tst: l 0.175 a 0.950 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.120sec
# Epoch 298 tr: l 0.127 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 23.143sec(train) 1.592sec(infer)
# Epoch 298 tst: l 0.175 a 0.950 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.118sec
# Epoch 299 tr: l 0.124 a 0.961 clct[np.int64(299), np.int64(300), np.int64(300), np.int64(301)] cl_acc 0.999  lr 0.100000 22.864sec(train) 1.593sec(infer)
# Epoch 299 tst: l 0.175 a 0.950 clct[np.int64(49), np.int64(50), np.int64(50), np.int64(51)] cl_acc 0.995  1.113sec
# result written at output_dfca_gi/results.pickle
# checkpoint written at output_dfca_gi/checkpoint.pt
# ---train cluster Ended in 2.34 hour (8412.737 sec)

# %% [markdown]
# ## Plots

# %%
r_ifca = {}
r_dfca_gi = {}
r_dfca_li = {}

r_ifca['test_loss'] = []
r_ifca['test_acc'] = []
r_ifca['cl_acc'] = []
r_ifca['train_loss'] = []
for i in range(len(learning_rates)):
    r_ifca['test_loss'].append(ifca[i][0])
    r_ifca['test_acc'].append(ifca[i][1])
    r_ifca['cl_acc'].append(ifca[i][2])
    r_ifca['train_loss'].append(ifca[i][3])

r_dfca_gi['test_loss'] = []
r_dfca_gi['test_acc'] = []
r_dfca_gi['cl_acc'] = []
r_dfca_gi['train_loss'] = []
for i in range(len(learning_rates)):
    r_dfca_gi['test_loss'].append(dfca_gi[i][0])
    r_dfca_gi['test_acc'].append(dfca_gi[i][1])
    r_dfca_gi['cl_acc'].append(dfca_gi[i][2])
    r_dfca_gi['train_loss'].append(dfca_gi[i][3])

r_dfca_li['test_loss'] = []
r_dfca_li['test_acc'] = []
r_dfca_li['cl_acc'] = []
r_dfca_li['train_loss'] = []
for i in range(len(learning_rates)):
    r_dfca_li['test_loss'].append(dfca_li[i][0])
    r_dfca_li['test_acc'].append(dfca_li[i][1])
    r_dfca_li['cl_acc'].append(dfca_li[i][2])
    r_dfca_li['train_loss'].append(dfca_li[i][3])



os.makedirs('graphs', exist_ok=True)

for l in range(len(learning_rates)):

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['test_loss'][l], label='ifca', color='xkcd:azure')
    plt.plot(r_dfca_li['test_loss'][l], label='dfca-li', color='red')
    plt.plot(r_dfca_gi['test_loss'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('loss', fontsize=20)
    plt.title(f'Test Loss per Epoch (lr={learning_rates[l]})', fontsize=22, fontweight='bold')
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.legend(fontsize=20)
    plt.savefig(os.path.join('graphs', 'test_loss.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['train_loss'][l], label='ifca', color='xkcd:azure')
    plt.plot(r_dfca_li['train_loss'][l], label='dfca-li', color='red')
    plt.plot(r_dfca_gi['train_loss'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('loss', fontsize=20)
    plt.title(f'Train Loss per Epoch (lr={learning_rates[l]})', fontsize=22, fontweight='bold')
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.legend(fontsize=20)
    plt.savefig(os.path.join('graphs', 'train_loss.png'))

    plt.figure(figsize=(10,5))
    plt.plot(r_ifca['test_acc'][l], label='ifca', color='xkcd:azure')
    plt.plot(r_dfca_li['test_acc'][l], label='dfca-li', color='red')
    plt.plot(r_dfca_gi['test_acc'][l], label='dfca-gi', color='green')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('test accuracy', fontsize=20)
    plt.title(f'Test Accuracy per Epoch (lr={learning_rates[l]})', fontsize=22, fontweight='bold')
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.legend(fontsize=20)
    plt.savefig(os.path.join('graphs', 'test_acc.png'))

    plt.figure(figsize=(10,7))
    plt.ylim([0, 1.1])
    plt.plot(r_ifca['cl_acc'][l][:31], label='ifca', color='xkcd:azure', marker='o')
    plt.plot(r_dfca_li['cl_acc'][l][:31], label='dfca-li', color='red', marker='o')
    plt.plot(r_dfca_gi['cl_acc'][l][:31], label='dfca-gi', color='green', marker='o')
    plt.xlabel('epoch', fontsize=20)
    plt.ylabel('cluster acc', fontsize=20)
    plt.legend(fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.savefig(os.path.join('graphs', 'cluster_acc.png'))
